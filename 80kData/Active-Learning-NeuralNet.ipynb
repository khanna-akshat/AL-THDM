# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from tqdm import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score
import corner
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2  # Import L2 regularization
from sklearn.preprocessing import StandardScaler
# Out:
# 2023-11-16 23:24:04.471469: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-16 23:24:04.520235: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-16 23:24:04.521165: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-16 23:24:05.241222: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load and split the dataset

# %%
data = pd.read_csv('Alignment-1-Learning.csv')

# %%
data.head()
# Out:
#      mH1         mH2         mH3         mA1         mA2         mC1  \
# 0  125.0  389.681890  266.205554  357.716926  216.548541  437.974724
# 1  125.0  466.478864  389.569317  402.965051  380.172764  364.184617
# 2  125.0  220.948750  486.689377  537.099375  320.173513  243.467599
# 3  125.0  328.343580  323.472676  221.752325  348.389320  487.707855
# 4  125.0  335.247929  211.280269  206.867278  340.005918  207.546645
#
#           mC2  TanBeta1  TanBeta2  TanAlpha4  TanGamma1  TanGamma2  TanAlpha1  \
# 0  291.549211  1.825617  0.708838   5.560399  21.627008  24.836633   1.825617
# 1  381.934382  1.054113  0.609084  10.036226  20.546985  15.891286   1.054113
# 2  406.498383  1.303290  0.919230  13.261847  23.903331  21.670848   1.303290
# 3  305.971767  0.793804  0.669176  11.678012  12.508026  14.745824   0.793804
# 4  227.085078  2.043520  1.108583  16.270581  13.387200  20.521982   2.043520
#
#    TanAlpha2  Output
# 0   0.708838       1
# 1   0.609084       1
# 2   0.919230       1
# 3   0.669176       1
# 4   1.108583       1

# %%
#check for any empty cell in the database
data.isna().sum()
# Out:
# mH1          0
# mH2          0
# mH3          0
# mA1          0
# mA2          0
# mC1          0
# mC2          0
# TanBeta1     0
# TanBeta2     0
# TanAlpha4    0
# TanGamma1    0
# TanGamma2    0
# TanAlpha1    0
# TanAlpha2    0
# Output       0
# dtype: int64

# %%
#shuffle the dataframe

data_sh = data.sample(frac = 1.0, random_state = 52)

#reset the index

data_sh = data_sh.reset_index(drop=True)

# %%
#put feature variable to X and target variable to Y

X = data_sh.drop('Output', axis = 1)
Y = data_sh['Output']

# %%
# data preprocessing
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

column_names = ['mH1','mH2','mH3','mA1','mA2','mC1','mC2','TanBeta1','TanBeta2','TanAlpha4','TanGamma1','TanGamma2','TanAlpha1','TanAlpha2']

X = pd.DataFrame(X_scaled, columns=column_names)

# %%
#Split into train data and test data

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.94, random_state = 52)

#Split the training data further into labeled and unlabeled dataset

X_labeled, X_unlabeled, Y_labeled, Y_unlabeled = train_test_split(X_train, Y_train, test_size = 0.9995, random_state = 52)

# %%
print(f"Total Number of datapoints: {len(X)}")
print(f"Number of labeled datapoints: {len(X_labeled)}")
print(f"Number of unlabeled datapoints: {len(X_unlabeled)}")
print(f"Number of test datapoints: {len(X_test)}")
# Out:
# Total Number of datapoints: 81736
# Number of labeled datapoints: 2
# Number of unlabeled datapoints: 4902
# Number of test datapoints: 76832

# %%
frac_unlabeled = Y_unlabeled.sum()/len(Y_unlabeled)
frac_labeled = Y_labeled.sum()/len(Y_labeled)
frac_test = Y_test.sum()/len(Y_test)

# %%
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
print(f"Fraction of allowed points in unlabeled dataset: {frac_unlabeled}")
print(f"Fraction of allowed points in test dataset: {frac_test}")
# Out:
# Fraction of allowed points in labeled dataset: 0.5
# Fraction of allowed points in unlabeled dataset: 0.4934720522235822
# Fraction of allowed points in test dataset: 0.4986984589754269

# %% [markdown]
# ## Neural Network Model 1

# %%
# Set random seeds for reproducibility
seed_value = 52
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

# %%
#define your model
model = keras.Sequential()

# Add input layer with 14 input parameters
model.add(layers.Input(shape=(X.shape[1],)))

model.add(layers.Dense(128, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(64, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(1, activation = 'sigmoid'))

custom_learning_rate = 0.001  # You can adjust this value as needed

# Compile the model with a custom learning rate
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
model.compile(loss='binary_crossentropy', optimizer=custom_optimizer)

# Display the model summary to see the architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32)                0
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9121 (35.63 KB)
# Trainable params: 8673 (33.88 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %% [markdown]
# ## Active Learning Loop

# %%
#active learning loop
num_iterations = 40

num_it_array = np.arange(1,num_iterations+2,1)
accuracy_array = np.zeros(num_iterations+1)
precision_array = np.zeros(num_iterations+1)
recall_array = np.zeros(num_iterations+1)
f1_array = np.zeros(num_iterations+1)

for iteration in range(num_iterations):
    #Train the model
    model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)
    
    #Get model predictions on the test data
    Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
    #Convert the predictions into binary
    Y_pred_binary = (Y_pred_test > 0.5).astype(int)
    
    #Calculate accuracy,precision,recall and F1 Score on the test set
    accuracy = accuracy_score(Y_test, Y_pred_binary)
    accuracy_array[iteration] = accuracy
    precision = precision_score(Y_test, Y_pred_binary)
    precision_array[iteration] = precision
    recall = recall_score(Y_test, Y_pred_binary)
    recall_array[iteration] = recall
    f1 = f1_score(Y_test, Y_pred_binary)
    f1_array[iteration] = f1
    frac_labeled = Y_labeled.sum()/len(Y_labeled)
    print(f"Iteration : {iteration + 1}: Test Accuracy = {accuracy:.6f}")
    print(f"Iteration : {iteration + 1}: Test Precision = {precision:.6f}")
    print(f"Iteration : {iteration + 1}: Test Recall = {recall:.6f}")
    print(f"Iteration : {iteration + 1}: Test F1 = {f1:.6f}")
    print(f"Iteration : {iteration + 1}: Fraction of allowed points in labeled dataset = {frac_labeled}")
    print(" ") #Print a blank line
    
    #Get model predictions on the unlabeled data
    Y_pred_unlabel = model.predict(X_unlabeled, verbose=0).ravel()
    
    #Calculate entropy
    entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)
    
    #Select the most uncertain samples
    num_samples_to_label = 2
    selected_indices = np.argsort(entropy)[-num_samples_to_label:]
    
    #move the selected samples from unlabeled to labeled data
    X_labeled = pd.concat([X_labeled, X_unlabeled.iloc[selected_indices]])
    Y_labeled = pd.concat([Y_labeled, pd.Series(Y_unlabeled.iloc[selected_indices])])
    
    #Remove the newly labeled samples from the unlabeled data
    X_unlabeled = X_unlabeled.drop(X_unlabeled.index[selected_indices])
    Y_unlabeled = Y_unlabeled.drop(Y_unlabeled.index[selected_indices])
    
#Train the final model on all labeled data 
model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)

#Evaluate the final model on the test data
Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
#Convert the predictions into binary
Y_pred_binary = (Y_pred_test > 0.5).astype(int)

#Calculate various metric scores
final_accuracy = accuracy_score(Y_test, Y_pred_binary)
accuracy_array[-1] = final_accuracy
final_precision = precision_score(Y_test, Y_pred_binary)
precision_array[-1] = final_precision
final_recall = recall_score(Y_test, Y_pred_binary)
recall_array[-1] = final_recall
final_f1 = f1_score(Y_test, Y_pred_binary)
f1_array[-1] = final_f1
frac_labeled = Y_labeled.sum()/len(Y_labeled)

print(f"Final Model Test Accuracy: {final_accuracy:.6f}")
print(f"Final Model Test Precision: {final_precision:.6f}")
print(f"Final Model Test Recall: {final_recall:.6f}")
print(f"Final Model Test F1: {final_f1:.6f}")
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
# Out:
# Iteration : 1: Test Accuracy = 0.746226
# Iteration : 1: Test Precision = 0.669635
# Iteration : 1: Test Recall = 0.969360
# Iteration : 1: Test F1 = 0.792092
# Iteration : 1: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 2: Test Accuracy = 0.876419
# Iteration : 2: Test Precision = 0.801406
# Iteration : 2: Test Recall = 1.000000
# Iteration : 2: Test F1 = 0.889756
# Iteration : 2: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 3: Test Accuracy = 0.905534
# Iteration : 3: Test Precision = 0.840922
# Iteration : 3: Test Recall = 0.999687
# Iteration : 3: Test F1 = 0.913457
# Iteration : 3: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 4: Test Accuracy = 0.962216
# Iteration : 4: Test Precision = 0.929571
# Iteration : 4: Test Recall = 1.000000
# Iteration : 4: Test F1 = 0.963500
# Iteration : 4: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 5: Test Accuracy = 0.980230
# Iteration : 5: Test Precision = 0.961868
# Iteration : 5: Test Recall = 1.000000
# Iteration : 5: Test F1 = 0.980563
# Iteration : 5: Fraction of allowed points in labeled dataset = 0.2
#
# Iteration : 6: Test Accuracy = 0.990160
# Iteration : 6: Test Precision = 0.980651
# Iteration : 6: Test Recall = 1.000000
# Iteration : 6: Test F1 = 0.990231
# Iteration : 6: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 7: Test Accuracy = 0.992581
# Iteration : 7: Test Precision = 0.988280
# Iteration : 7: Test Recall = 0.996946
# Iteration : 7: Test F1 = 0.992594
# Iteration : 7: Fraction of allowed points in labeled dataset = 0.14285714285714285
#
# Iteration : 8: Test Accuracy = 0.995210
# Iteration : 8: Test Precision = 0.990487
# Iteration : 8: Test Recall = 1.000000
# Iteration : 8: Test F1 = 0.995221
# Iteration : 8: Fraction of allowed points in labeled dataset = 0.1875
#
# Iteration : 9: Test Accuracy = 0.995939
# Iteration : 9: Test Precision = 0.991999
# Iteration : 9: Test Recall = 0.999922
# Iteration : 9: Test F1 = 0.995945
# Iteration : 9: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 10: Test Accuracy = 0.996082
# Iteration : 10: Test Precision = 0.992256
# Iteration : 10: Test Recall = 0.999948
# Iteration : 10: Test F1 = 0.996087
# Iteration : 10: Fraction of allowed points in labeled dataset = 0.15
#
# Iteration : 11: Test Accuracy = 0.997423
# Iteration : 11: Test Precision = 0.994859
# Iteration : 11: Test Recall = 1.000000
# Iteration : 11: Test F1 = 0.997423
# Iteration : 11: Fraction of allowed points in labeled dataset = 0.13636363636363635
#
# Iteration : 12: Test Accuracy = 0.997709
# Iteration : 12: Test Precision = 0.995762
# Iteration : 12: Test Recall = 0.999661
# Iteration : 12: Test F1 = 0.997708
# Iteration : 12: Fraction of allowed points in labeled dataset = 0.125
#
# Iteration : 13: Test Accuracy = 0.995458
# Iteration : 13: Test Precision = 0.995640
# Iteration : 13: Test Recall = 0.995250
# Iteration : 13: Test F1 = 0.995445
# Iteration : 13: Fraction of allowed points in labeled dataset = 0.11538461538461539
#
# Iteration : 14: Test Accuracy = 0.997813
# Iteration : 14: Test Precision = 0.995635
# Iteration : 14: Test Recall = 1.000000
# Iteration : 14: Test F1 = 0.997812
# Iteration : 14: Fraction of allowed points in labeled dataset = 0.17857142857142858
#
# Iteration : 15: Test Accuracy = 0.997983
# Iteration : 15: Test Precision = 0.996023
# Iteration : 15: Test Recall = 0.999948
# Iteration : 15: Test F1 = 0.997981
# Iteration : 15: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 16: Test Accuracy = 0.997449
# Iteration : 16: Test Precision = 0.996277
# Iteration : 16: Test Recall = 0.998617
# Iteration : 16: Test F1 = 0.997445
# Iteration : 16: Fraction of allowed points in labeled dataset = 0.15625
#
# Iteration : 17: Test Accuracy = 0.998946
# Iteration : 17: Test Precision = 0.997890
# Iteration : 17: Test Recall = 1.000000
# Iteration : 17: Test F1 = 0.998944
# Iteration : 17: Fraction of allowed points in labeled dataset = 0.20588235294117646
#
# Iteration : 18: Test Accuracy = 0.999232
# Iteration : 18: Test Precision = 0.998489
# Iteration : 18: Test Recall = 0.999974
# Iteration : 18: Test F1 = 0.999231
# Iteration : 18: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 19: Test Accuracy = 0.998959
# Iteration : 19: Test Precision = 0.998722
# Iteration : 19: Test Recall = 0.999191
# Iteration : 19: Test F1 = 0.998956
# Iteration : 19: Fraction of allowed points in labeled dataset = 0.2631578947368421
#
# Iteration : 20: Test Accuracy = 0.999167
# Iteration : 20: Test Precision = 0.998332
# Iteration : 20: Test Recall = 1.000000
# Iteration : 20: Test F1 = 0.999166
# Iteration : 20: Fraction of allowed points in labeled dataset = 0.3
#
# Iteration : 21: Test Accuracy = 0.999388
# Iteration : 21: Test Precision = 0.998775
# Iteration : 21: Test Recall = 1.000000
# Iteration : 21: Test F1 = 0.999387
# Iteration : 21: Fraction of allowed points in labeled dataset = 0.30952380952380953
#
# Iteration : 22: Test Accuracy = 0.999362
# Iteration : 22: Test Precision = 0.998723
# Iteration : 22: Test Recall = 1.000000
# Iteration : 22: Test F1 = 0.999361
# Iteration : 22: Fraction of allowed points in labeled dataset = 0.3181818181818182
#
# Iteration : 23: Test Accuracy = 0.999349
# Iteration : 23: Test Precision = 0.998697
# Iteration : 23: Test Recall = 1.000000
# Iteration : 23: Test F1 = 0.999348
# Iteration : 23: Fraction of allowed points in labeled dataset = 0.34782608695652173
#
# Iteration : 24: Test Accuracy = 0.999297
# Iteration : 24: Test Precision = 0.998593
# Iteration : 24: Test Recall = 1.000000
# Iteration : 24: Test F1 = 0.999296
# Iteration : 24: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 25: Test Accuracy = 0.999414
# Iteration : 25: Test Precision = 0.998827
# Iteration : 25: Test Recall = 1.000000
# Iteration : 25: Test F1 = 0.999413
# Iteration : 25: Fraction of allowed points in labeled dataset = 0.38
#
# Iteration : 26: Test Accuracy = 0.999401
# Iteration : 26: Test Precision = 0.998801
# Iteration : 26: Test Recall = 1.000000
# Iteration : 26: Test F1 = 0.999400
# Iteration : 26: Fraction of allowed points in labeled dataset = 0.40384615384615385
#
# Iteration : 27: Test Accuracy = 0.999427
# Iteration : 27: Test Precision = 0.998853
# Iteration : 27: Test Recall = 1.000000
# Iteration : 27: Test F1 = 0.999426
# Iteration : 27: Fraction of allowed points in labeled dataset = 0.42592592592592593
#
# Iteration : 28: Test Accuracy = 0.999427
# Iteration : 28: Test Precision = 0.998853
# Iteration : 28: Test Recall = 1.000000
# Iteration : 28: Test F1 = 0.999426
# Iteration : 28: Fraction of allowed points in labeled dataset = 0.44642857142857145
#
# Iteration : 29: Test Accuracy = 0.999453
# Iteration : 29: Test Precision = 0.998905
# Iteration : 29: Test Recall = 1.000000
# Iteration : 29: Test F1 = 0.999452
# Iteration : 29: Fraction of allowed points in labeled dataset = 0.4482758620689655
#
# Iteration : 30: Test Accuracy = 0.999531
# Iteration : 30: Test Precision = 0.999061
# Iteration : 30: Test Recall = 1.000000
# Iteration : 30: Test F1 = 0.999530
# Iteration : 30: Fraction of allowed points in labeled dataset = 0.43333333333333335
#
# Iteration : 31: Test Accuracy = 0.999531
# Iteration : 31: Test Precision = 0.999061
# Iteration : 31: Test Recall = 1.000000
# Iteration : 31: Test F1 = 0.999530
# Iteration : 31: Fraction of allowed points in labeled dataset = 0.43548387096774194
#
# Iteration : 32: Test Accuracy = 0.999531
# Iteration : 32: Test Precision = 0.999061
# Iteration : 32: Test Recall = 1.000000
# Iteration : 32: Test F1 = 0.999530
# Iteration : 32: Fraction of allowed points in labeled dataset = 0.453125
#
# Iteration : 33: Test Accuracy = 0.999505
# Iteration : 33: Test Precision = 0.999009
# Iteration : 33: Test Recall = 1.000000
# Iteration : 33: Test F1 = 0.999504
# Iteration : 33: Fraction of allowed points in labeled dataset = 0.4696969696969697
#
# Iteration : 34: Test Accuracy = 0.999388
# Iteration : 34: Test Precision = 0.998775
# Iteration : 34: Test Recall = 1.000000
# Iteration : 34: Test F1 = 0.999387
# Iteration : 34: Fraction of allowed points in labeled dataset = 0.4852941176470588
#
# Iteration : 35: Test Accuracy = 0.999440
# Iteration : 35: Test Precision = 0.998879
# Iteration : 35: Test Recall = 1.000000
# Iteration : 35: Test F1 = 0.999439
# Iteration : 35: Fraction of allowed points in labeled dataset = 0.4857142857142857
# Iteration : 36: Test Accuracy = 0.999518
# Iteration : 36: Test Precision = 0.999035
# Iteration : 36: Test Recall = 1.000000
# Iteration : 36: Test F1 = 0.999517
# Iteration : 36: Fraction of allowed points in labeled dataset = 0.4722222222222222
#
# Iteration : 37: Test Accuracy = 0.999466
# Iteration : 37: Test Precision = 0.998931
# Iteration : 37: Test Recall = 1.000000
# Iteration : 37: Test F1 = 0.999465
# Iteration : 37: Fraction of allowed points in labeled dataset = 0.4594594594594595
#
# Iteration : 38: Test Accuracy = 0.999544
# Iteration : 38: Test Precision = 0.999087
# Iteration : 38: Test Recall = 1.000000
# Iteration : 38: Test F1 = 0.999543
# Iteration : 38: Fraction of allowed points in labeled dataset = 0.47368421052631576
#
# Iteration : 39: Test Accuracy = 0.999531
# Iteration : 39: Test Precision = 0.999061
# Iteration : 39: Test Recall = 1.000000
# Iteration : 39: Test F1 = 0.999530
# Iteration : 39: Fraction of allowed points in labeled dataset = 0.48717948717948717
#
# Iteration : 40: Test Accuracy = 0.999505
# Iteration : 40: Test Precision = 0.999009
# Iteration : 40: Test Recall = 1.000000
# Iteration : 40: Test F1 = 0.999504
# Iteration : 40: Fraction of allowed points in labeled dataset = 0.475
#
# Final Model Test Accuracy: 0.999505
# Final Model Test Precision: 0.999009
# Final Model Test Recall: 1.000000
# Final Model Test F1: 0.999504
# Fraction of allowed points in labeled dataset: 0.4634146341463415

# %%
# Plot iteration vs accuracy

plt.figure(figsize=(10, 9))

plt.subplot(2,2,1)
plt.plot(num_it_array, accuracy_array)
plt.title("Plot of iterations vs accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")

# Plot iteration vs precision

plt.subplot(2,2,2)
plt.plot(num_it_array, precision_array)
plt.title("Plot of iterations vs precision")
plt.xlabel("Iteration")
plt.ylabel("Precision")

# Plot iteration vs recall

plt.subplot(2,2,3)
plt.plot(num_it_array, recall_array)
plt.title("Plot of iterations vs recall")
plt.xlabel("Iteration")
plt.ylabel("Recall")

# Plot iteration vs f1-score

plt.subplot(2,2,4)
plt.plot(num_it_array, f1_array)
plt.title("Plot of iterations vs f1-score")
plt.xlabel("Iteration")
plt.ylabel("F1-score")
# Out:
# Text(0, 0.5, 'F1-score')

# %%
#Plot the ROC curve

Y_final_pred_prob = model.predict(X_test)

fpr, tpr, thresholds = roc_curve(Y_test, Y_final_pred_prob)
# Out:
# 2401/2401 [==============================] - 2s 859us/step

# %%
plt.figure(figsize=(8, 6))
plt.scatter(fpr, tpr, label='Neural network ROC Curve')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# ## Selecting most uncertain points from unlabeled dataset

# %%
#selecting the most uncertain indices from the first model

entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)

num_samples_to_select = 2
    
selected_indices = np.argsort(entropy)[-num_samples_to_select:]

# %%
selected_indices
# Out:
# array([4637, 4595])

# %%
np.where(Y_unlabeled.iloc[selected_indices]==1)
# Out:
# (array([0]),)

# %%
#Retrieve the selected rows for the second neural network

X_train_2 = X_unlabeled.iloc[selected_indices]
Y_train_2 = Y_unlabeled.iloc[selected_indices]

# %%
#concatenate X and Y train
combined = pd.concat([X_train_2, Y_train_2],axis=1)

# %%
#Iterate over each row in X_train_2 and Y_train_2 and find the indices
indices_to_remove = []
for index, row in X_train_2.iterrows():
    indices_to_remove.extend(combined[combined[X.columns].eq(row.to_dict()).all(1)].index)

# %%
indices_to_remove
# Out:
# [28741, 24906]

# %%
#drop these indices in the total dataset
X = X.drop(indices_to_remove)
Y = Y.drop(indices_to_remove)

# %%
#Split into train data and test data

X_unlabeled, X_test, Y_unlabeled, Y_test = train_test_split(X, Y, test_size = 0.94, random_state = 42)

X_labeled = X_train_2
Y_labeled = Y_train_2

# %%
print(f"Total Number of datapoints: {len(X)}")
print(f"Number of labeled datapoints: {len(X_labeled)}")
print(f"Number of unlabeled datapoints: {len(X_unlabeled)}")
print(f"Number of test datapoints: {len(X_test)}")
# Out:
# Total Number of datapoints: 81734
# Number of labeled datapoints: 2
# Number of unlabeled datapoints: 4904
# Number of test datapoints: 76830

# %%
frac_unlabeled = Y_unlabeled.sum()/len(Y_unlabeled)
frac_labeled = Y_labeled.sum()/len(Y_labeled)
frac_test = Y_test.sum()/len(Y_test)

# %%
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
print(f"Fraction of allowed points in unlabeled dataset: {frac_unlabeled}")
print(f"Fraction of allowed points in test dataset: {frac_test}")
# Out:
# Fraction of allowed points in labeled dataset: 0.5
# Fraction of allowed points in unlabeled dataset: 0.5
# Fraction of allowed points in test dataset: 0.4982819211245607

# %% [markdown]
# ## Neural Network Model 2

# %%
# Set random seeds for reproducibility
seed_value = 42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

# %%
#define your model
model_2 = keras.Sequential()

# Add input layer with 14 input parameters
model_2.add(layers.Input(shape=(X.shape[1],)))

model_2.add(layers.Dense(128, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(64, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(1, activation = 'sigmoid'))

custom_learning_rate = 0.001  # You can adjust this value as needed

# Compile the model with a custom learning rate
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
model_2.compile(loss='binary_crossentropy', optimizer=custom_optimizer)

# Display the model summary to see the architecture
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               1920
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 32)                4128
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 64)                2112
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  batch_normalization_6 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32)                0
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 11297 (44.13 KB)
# Trainable params: 10785 (42.13 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## Active Learning Loop

# %%
#active learning loop
num_iterations = 40

num_it_array = np.arange(1,num_iterations+2,1)
accuracy_array = np.zeros(num_iterations+1)
precision_array = np.zeros(num_iterations+1)
recall_array = np.zeros(num_iterations+1)
f1_array = np.zeros(num_iterations+1)

for iteration in range(num_iterations):
    #Train the model
    model_2.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)
    
    #Get model predictions on the test data
    Y_pred_test = model_2.predict(X_test, verbose=0).ravel()   
    
    #Convert the predictions into binary
    Y_pred_binary = (Y_pred_test > 0.5).astype(int)
    
    #Calculate accuracy,precision,recall and F1 Score on the test set
    accuracy = accuracy_score(Y_test, Y_pred_binary)
    accuracy_array[iteration] = accuracy
    precision = precision_score(Y_test, Y_pred_binary)
    precision_array[iteration] = precision
    recall = recall_score(Y_test, Y_pred_binary)
    recall_array[iteration] = recall
    f1 = f1_score(Y_test, Y_pred_binary)
    f1_array[iteration] = f1
    frac_labeled = Y_labeled.sum()/len(Y_labeled)
    print(f"Iteration : {iteration + 1}: Test Accuracy = {accuracy:.6f}")
    print(f"Iteration : {iteration + 1}: Test Precision = {precision:.6f}")
    print(f"Iteration : {iteration + 1}: Test Recall = {recall:.6f}")
    print(f"Iteration : {iteration + 1}: Test F1 = {f1:.6f}")
    print(f"Iteration : {iteration + 1}: Fraction of allowed points in labeled dataset = {frac_labeled}")
    print(" ") #Print a blank line
    
    #Get model predictions on the unlabeled data
    Y_pred_unlabel = model_2.predict(X_unlabeled, verbose=0).ravel()
    
    #Calculate entropy
    entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)
    
    #Select the most uncertain samples
    num_samples_to_label = 2
    selected_indices = np.argsort(entropy)[-num_samples_to_label:]
    
    #move the selected samples from unlabeled to labeled data
    X_labeled = pd.concat([X_labeled, X_unlabeled.iloc[selected_indices]])
    Y_labeled = pd.concat([Y_labeled, pd.Series(Y_unlabeled.iloc[selected_indices])])
    
    #Remove the newly labeled samples from the unlabeled data
    X_unlabeled = X_unlabeled.drop(X_unlabeled.index[selected_indices])
    Y_unlabeled = Y_unlabeled.drop(Y_unlabeled.index[selected_indices])
    
#Train the final model on all labeled data 
model_2.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)

#Evaluate the final model on the test data
Y_pred_test = model_2.predict(X_test, verbose=0).ravel()   
    
#Convert the predictions into binary
Y_pred_binary = (Y_pred_test > 0.5).astype(int)

#Calculate various metric scores
final_accuracy = accuracy_score(Y_test, Y_pred_binary)
accuracy_array[-1] = final_accuracy
final_precision = precision_score(Y_test, Y_pred_binary)
precision_array[-1] = final_precision
final_recall = recall_score(Y_test, Y_pred_binary)
recall_array[-1] = final_recall
final_f1 = f1_score(Y_test, Y_pred_binary)
f1_array[-1] = final_f1
frac_labeled = Y_labeled.sum()/len(Y_labeled)

print(f"Final Model Test Accuracy: {final_accuracy:.6f}")
print(f"Final Model Test Precision: {final_precision:.6f}")
print(f"Final Model Test Recall: {final_recall:.6f}")
print(f"Final Model Test F1: {final_f1:.6f}")
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
# Out:
# Iteration : 1: Test Accuracy = 0.649746
# Iteration : 1: Test Precision = 0.652326
# Iteration : 1: Test Recall = 0.636105
# Iteration : 1: Test F1 = 0.644114
# Iteration : 1: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 2: Test Accuracy = 0.755916
# Iteration : 2: Test Precision = 0.671316
# Iteration : 2: Test Recall = 0.999530
# Iteration : 2: Test F1 = 0.803186
# Iteration : 2: Fraction of allowed points in labeled dataset = 0.75
#
# Iteration : 3: Test Accuracy = 0.817441
# Iteration : 3: Test Precision = 0.731863
# Iteration : 3: Test Recall = 1.000000
# Iteration : 3: Test F1 = 0.845174
# Iteration : 3: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 4: Test Accuracy = 0.861408
# Iteration : 4: Test Precision = 0.782387
# Iteration : 4: Test Recall = 1.000000
# Iteration : 4: Test F1 = 0.877910
# Iteration : 4: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 5: Test Accuracy = 0.927047
# Iteration : 5: Test Precision = 0.872645
# Iteration : 5: Test Recall = 0.999451
# Iteration : 5: Test F1 = 0.931754
# Iteration : 5: Fraction of allowed points in labeled dataset = 0.3
#
# Iteration : 6: Test Accuracy = 0.970910
# Iteration : 6: Test Precision = 0.946669
# Iteration : 6: Test Recall = 0.997832
# Iteration : 6: Test F1 = 0.971578
# Iteration : 6: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 7: Test Accuracy = 0.985058
# Iteration : 7: Test Precision = 0.970886
# Iteration : 7: Test Recall = 1.000000
# Iteration : 7: Test F1 = 0.985228
# Iteration : 7: Fraction of allowed points in labeled dataset = 0.2857142857142857
#
# Iteration : 8: Test Accuracy = 0.986958
# Iteration : 8: Test Precision = 0.974494
# Iteration : 8: Test Recall = 1.000000
# Iteration : 8: Test F1 = 0.987082
# Iteration : 8: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 9: Test Accuracy = 0.990798
# Iteration : 9: Test Precision = 0.981867
# Iteration : 9: Test Recall = 1.000000
# Iteration : 9: Test F1 = 0.990851
# Iteration : 9: Fraction of allowed points in labeled dataset = 0.2222222222222222
#
# Iteration : 10: Test Accuracy = 0.993310
# Iteration : 10: Test Precision = 0.986752
# Iteration : 10: Test Recall = 1.000000
# Iteration : 10: Test F1 = 0.993332
# Iteration : 10: Fraction of allowed points in labeled dataset = 0.2
#
# Iteration : 11: Test Accuracy = 0.993870
# Iteration : 11: Test Precision = 0.987872
# Iteration : 11: Test Recall = 0.999974
# Iteration : 11: Test F1 = 0.993886
# Iteration : 11: Fraction of allowed points in labeled dataset = 0.18181818181818182
#
# Iteration : 12: Test Accuracy = 0.995900
# Iteration : 12: Test Precision = 0.991890
# Iteration : 12: Test Recall = 0.999948
# Iteration : 12: Test F1 = 0.995903
# Iteration : 12: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 13: Test Accuracy = 0.993232
# Iteration : 13: Test Precision = 0.992000
# Iteration : 13: Test Recall = 0.994436
# Iteration : 13: Test F1 = 0.993217
# Iteration : 13: Fraction of allowed points in labeled dataset = 0.15384615384615385
#
# Iteration : 14: Test Accuracy = 0.996499
# Iteration : 14: Test Precision = 0.993048
# Iteration : 14: Test Recall = 0.999974
# Iteration : 14: Test F1 = 0.996499
# Iteration : 14: Fraction of allowed points in labeled dataset = 0.21428571428571427
#
# Iteration : 15: Test Accuracy = 0.997267
# Iteration : 15: Test Precision = 0.994544
# Iteration : 15: Test Recall = 1.000000
# Iteration : 15: Test F1 = 0.997265
# Iteration : 15: Fraction of allowed points in labeled dataset = 0.23333333333333334
#
# Iteration : 16: Test Accuracy = 0.997084
# Iteration : 16: Test Precision = 0.994183
# Iteration : 16: Test Recall = 1.000000
# Iteration : 16: Test F1 = 0.997083
# Iteration : 16: Fraction of allowed points in labeled dataset = 0.21875
#
# Iteration : 17: Test Accuracy = 0.997970
# Iteration : 17: Test Precision = 0.995942
# Iteration : 17: Test Recall = 1.000000
# Iteration : 17: Test F1 = 0.997967
# Iteration : 17: Fraction of allowed points in labeled dataset = 0.20588235294117646
#
# Iteration : 18: Test Accuracy = 0.998920
# Iteration : 18: Test Precision = 0.997863
# Iteration : 18: Test Recall = 0.999974
# Iteration : 18: Test F1 = 0.998917
# Iteration : 18: Fraction of allowed points in labeled dataset = 0.19444444444444445
#
# Iteration : 19: Test Accuracy = 0.999193
# Iteration : 19: Test Precision = 0.998383
# Iteration : 19: Test Recall = 1.000000
# Iteration : 19: Test F1 = 0.999191
# Iteration : 19: Fraction of allowed points in labeled dataset = 0.21052631578947367
#
# Iteration : 20: Test Accuracy = 0.999141
# Iteration : 20: Test Precision = 0.998279
# Iteration : 20: Test Recall = 1.000000
# Iteration : 20: Test F1 = 0.999139
# Iteration : 20: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 21: Test Accuracy = 0.999271
# Iteration : 21: Test Precision = 0.998539
# Iteration : 21: Test Recall = 1.000000
# Iteration : 21: Test F1 = 0.999269
# Iteration : 21: Fraction of allowed points in labeled dataset = 0.2619047619047619
#
# Iteration : 22: Test Accuracy = 0.999050
# Iteration : 22: Test Precision = 0.998097
# Iteration : 22: Test Recall = 1.000000
# Iteration : 22: Test F1 = 0.999047
# Iteration : 22: Fraction of allowed points in labeled dataset = 0.29545454545454547
#
# Iteration : 23: Test Accuracy = 0.999115
# Iteration : 23: Test Precision = 0.998227
# Iteration : 23: Test Recall = 1.000000
# Iteration : 23: Test F1 = 0.999113
# Iteration : 23: Fraction of allowed points in labeled dataset = 0.2826086956521739
#
# Iteration : 24: Test Accuracy = 0.999232
# Iteration : 24: Test Precision = 0.998461
# Iteration : 24: Test Recall = 1.000000
# Iteration : 24: Test F1 = 0.999230
# Iteration : 24: Fraction of allowed points in labeled dataset = 0.3125
#
# Iteration : 25: Test Accuracy = 0.999206
# Iteration : 25: Test Precision = 0.998409
# Iteration : 25: Test Recall = 1.000000
# Iteration : 25: Test F1 = 0.999204
# Iteration : 25: Fraction of allowed points in labeled dataset = 0.32
#
# Iteration : 26: Test Accuracy = 0.999362
# Iteration : 26: Test Precision = 0.998722
# Iteration : 26: Test Recall = 1.000000
# Iteration : 26: Test F1 = 0.999360
# Iteration : 26: Fraction of allowed points in labeled dataset = 0.34615384615384615
#
# Iteration : 27: Test Accuracy = 0.999297
# Iteration : 27: Test Precision = 0.998591
# Iteration : 27: Test Recall = 1.000000
# Iteration : 27: Test F1 = 0.999295
# Iteration : 27: Fraction of allowed points in labeled dataset = 0.37037037037037035
#
# Iteration : 28: Test Accuracy = 0.999310
# Iteration : 28: Test Precision = 0.998617
# Iteration : 28: Test Recall = 1.000000
# Iteration : 28: Test F1 = 0.999308
# Iteration : 28: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 29: Test Accuracy = 0.999323
# Iteration : 29: Test Precision = 0.998644
# Iteration : 29: Test Recall = 1.000000
# Iteration : 29: Test F1 = 0.999321
# Iteration : 29: Fraction of allowed points in labeled dataset = 0.39655172413793105
#
# Iteration : 30: Test Accuracy = 0.999518
# Iteration : 30: Test Precision = 0.999034
# Iteration : 30: Test Recall = 1.000000
# Iteration : 30: Test F1 = 0.999517
# Iteration : 30: Fraction of allowed points in labeled dataset = 0.4166666666666667
#
# Iteration : 31: Test Accuracy = 0.999505
# Iteration : 31: Test Precision = 0.999008
# Iteration : 31: Test Recall = 1.000000
# Iteration : 31: Test F1 = 0.999504
# Iteration : 31: Fraction of allowed points in labeled dataset = 0.43548387096774194
#
# Iteration : 32: Test Accuracy = 0.999440
# Iteration : 32: Test Precision = 0.998878
# Iteration : 32: Test Recall = 1.000000
# Iteration : 32: Test F1 = 0.999439
# Iteration : 32: Fraction of allowed points in labeled dataset = 0.421875
#
# Iteration : 33: Test Accuracy = 0.999466
# Iteration : 33: Test Precision = 0.998930
# Iteration : 33: Test Recall = 1.000000
# Iteration : 33: Test F1 = 0.999465
# Iteration : 33: Fraction of allowed points in labeled dataset = 0.4393939393939394
#
# Iteration : 34: Test Accuracy = 0.999258
# Iteration : 34: Test Precision = 0.998513
# Iteration : 34: Test Recall = 1.000000
# Iteration : 34: Test F1 = 0.999256
# Iteration : 34: Fraction of allowed points in labeled dataset = 0.45588235294117646
#
# Iteration : 35: Test Accuracy = 0.999414
# Iteration : 35: Test Precision = 0.998826
# Iteration : 35: Test Recall = 1.000000
# Iteration : 35: Test F1 = 0.999413
# Iteration : 35: Fraction of allowed points in labeled dataset = 0.44285714285714284
# Iteration : 36: Test Accuracy = 0.999479
# Iteration : 36: Test Precision = 0.998956
# Iteration : 36: Test Recall = 1.000000
# Iteration : 36: Test F1 = 0.999478
# Iteration : 36: Fraction of allowed points in labeled dataset = 0.4583333333333333
#
# Iteration : 37: Test Accuracy = 0.999492
# Iteration : 37: Test Precision = 0.998982
# Iteration : 37: Test Recall = 1.000000
# Iteration : 37: Test F1 = 0.999491
# Iteration : 37: Fraction of allowed points in labeled dataset = 0.47297297297297297
#
# Iteration : 38: Test Accuracy = 0.999479
# Iteration : 38: Test Precision = 0.998956
# Iteration : 38: Test Recall = 1.000000
# Iteration : 38: Test F1 = 0.999478
# Iteration : 38: Fraction of allowed points in labeled dataset = 0.4605263157894737
#
# Iteration : 39: Test Accuracy = 0.999518
# Iteration : 39: Test Precision = 0.999034
# Iteration : 39: Test Recall = 1.000000
# Iteration : 39: Test F1 = 0.999517
# Iteration : 39: Fraction of allowed points in labeled dataset = 0.44871794871794873
#
# Iteration : 40: Test Accuracy = 0.999531
# Iteration : 40: Test Precision = 0.999061
# Iteration : 40: Test Recall = 1.000000
# Iteration : 40: Test F1 = 0.999530
# Iteration : 40: Fraction of allowed points in labeled dataset = 0.4375
#
# Final Model Test Accuracy: 0.999583
# Final Model Test Precision: 0.999165
# Final Model Test Recall: 1.000000
# Final Model Test F1: 0.999582
# Fraction of allowed points in labeled dataset: 0.45121951219512196

# %%
# Plot iteration vs accuracy

plt.figure(figsize=(10, 9))

plt.subplot(2,2,1)
plt.plot(num_it_array, accuracy_array)
plt.title("Plot of iterations vs accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")

# Plot iteration vs precision

plt.subplot(2,2,2)
plt.plot(num_it_array, precision_array)
plt.title("Plot of iterations vs precision")
plt.xlabel("Iteration")
plt.ylabel("Precision")

# Plot iteration vs recall

plt.subplot(2,2,3)
plt.plot(num_it_array, recall_array)
plt.title("Plot of iterations vs recall")
plt.xlabel("Iteration")
plt.ylabel("Recall")

# Plot iteration vs f1-score

plt.subplot(2,2,4)
plt.plot(num_it_array, f1_array)
plt.title("Plot of iterations vs f1-score")
plt.xlabel("Iteration")
plt.ylabel("F1-score")
# Out:
# Text(0, 0.5, 'F1-score')

# %% [markdown]
# ## Using Sinc Activation Function

# %%
def sinc_activation(x):
    return tf.where(tf.equal(x, 0), tf.ones_like(x), tf.sin(x) / x)

# %%
#define your model
model = keras.Sequential()

# Add input layer with 14 input parameters
model.add(layers.Input(shape=(X.shape[1],)))

model.add(layers.Dense(128, kernel_regularizer=l2(0.001)))
#model.add(layers.BatchNormalization())
model.add(layers.Activation(sinc_activation))
#model.add(layers.Dropout(0.5))

model.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
#model.add(layers.BatchNormalization())
model.add(layers.Activation(sinc_activation))
#model.add(layers.Dropout(0.5))

model.add(layers.Dense(64, kernel_regularizer=l2(0.001)))
#model.add(layers.BatchNormalization())
model.add(layers.Activation(sinc_activation))
#model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation = 'sigmoid'))

custom_learning_rate = 0.001  # You can adjust this value as needed

# Compile the model with a custom learning rate
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
model.compile(loss='binary_crossentropy', optimizer=custom_optimizer)

# Display the model summary to see the architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  activation (Activation)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  activation_1 (Activation)   (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 8225 (32.13 KB)
# Trainable params: 8225 (32.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#active learning loop
num_iterations = 40

num_it_array = np.arange(1,num_iterations+2,1)
accuracy_array = np.zeros(num_iterations+1)
precision_array = np.zeros(num_iterations+1)
recall_array = np.zeros(num_iterations+1)
f1_array = np.zeros(num_iterations+1)

for iteration in range(num_iterations):
    #Train the model
    model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)
    
    #Get model predictions on the test data
    Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
    #Convert the predictions into binary
    Y_pred_binary = (Y_pred_test > 0.5).astype(int)
    
    #Calculate accuracy,precision,recall and F1 Score on the test set
    accuracy = accuracy_score(Y_test, Y_pred_binary)
    accuracy_array[iteration] = accuracy
    precision = precision_score(Y_test, Y_pred_binary)
    precision_array[iteration] = precision
    recall = recall_score(Y_test, Y_pred_binary)
    recall_array[iteration] = recall
    f1 = f1_score(Y_test, Y_pred_binary)
    f1_array[iteration] = f1
    frac_labeled = Y_labeled.sum()/len(Y_labeled)
    print(f"Iteration : {iteration + 1}: Test Accuracy = {accuracy:.6f}")
    print(f"Iteration : {iteration + 1}: Test Precision = {precision:.6f}")
    print(f"Iteration : {iteration + 1}: Test Recall = {recall:.6f}")
    print(f"Iteration : {iteration + 1}: Test F1 = {f1:.6f}")
    print(f"Iteration : {iteration + 1}: Fraction of allowed points in labeled dataset = {frac_labeled}")
    print(" ") #Print a blank line
    
    #Get model predictions on the unlabeled data
    Y_pred_unlabel = model.predict(X_unlabeled, verbose=0).ravel()
    
    #Calculate entropy
    entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)
    
    #Select the most uncertain samples
    num_samples_to_label = 2
    selected_indices = np.argsort(entropy)[-num_samples_to_label:]
    
    #move the selected samples from unlabeled to labeled data
    X_labeled = pd.concat([X_labeled, X_unlabeled.iloc[selected_indices]])
    Y_labeled = pd.concat([Y_labeled, pd.Series(Y_unlabeled.iloc[selected_indices])])
    
    #Remove the newly labeled samples from the unlabeled data
    X_unlabeled = X_unlabeled.drop(X_unlabeled.index[selected_indices])
    Y_unlabeled = Y_unlabeled.drop(Y_unlabeled.index[selected_indices])
    
#Train the final model on all labeled data 
model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)

#Evaluate the final model on the test data
Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
#Convert the predictions into binary
Y_pred_binary = (Y_pred_test > 0.5).astype(int)

#Calculate various metric scores
final_accuracy = accuracy_score(Y_test, Y_pred_binary)
accuracy_array[-1] = final_accuracy
final_precision = precision_score(Y_test, Y_pred_binary)
precision_array[-1] = final_precision
final_recall = recall_score(Y_test, Y_pred_binary)
recall_array[-1] = final_recall
final_f1 = f1_score(Y_test, Y_pred_binary)
f1_array[-1] = final_f1
frac_labeled = Y_labeled.sum()/len(Y_labeled)

print(f"Final Model Test Accuracy: {final_accuracy:.6f}")
print(f"Final Model Test Precision: {final_precision:.6f}")
print(f"Final Model Test Recall: {final_recall:.6f}")
print(f"Final Model Test F1: {final_f1:.6f}")
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
# Out:
# Iteration : 1: Test Accuracy = 0.630115
# Iteration : 1: Test Precision = 0.576360
# Iteration : 1: Test Recall = 0.974815
# Iteration : 1: Test F1 = 0.724411
# Iteration : 1: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 2: Test Accuracy = 0.643274
# Iteration : 2: Test Precision = 0.819995
# Iteration : 2: Test Recall = 0.364756
# Iteration : 2: Test F1 = 0.504913
# Iteration : 2: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 3: Test Accuracy = 0.700880
# Iteration : 3: Test Precision = 0.627325
# Iteration : 3: Test Recall = 0.985881
# Iteration : 3: Test F1 = 0.766756
# Iteration : 3: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 4: Test Accuracy = 0.772243
# Iteration : 4: Test Precision = 0.689153
# Iteration : 4: Test Recall = 0.989717
# Iteration : 4: Test F1 = 0.812530
# Iteration : 4: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 5: Test Accuracy = 0.874557
# Iteration : 5: Test Precision = 0.822849
# Iteration : 5: Test Recall = 0.953805
# Iteration : 5: Test F1 = 0.883501
# Iteration : 5: Fraction of allowed points in labeled dataset = 0.3
#
# Iteration : 6: Test Accuracy = 0.965652
# Iteration : 6: Test Precision = 0.935563
# Iteration : 6: Test Recall = 1.000000
# Iteration : 6: Test F1 = 0.966709
# Iteration : 6: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 7: Test Accuracy = 0.977080
# Iteration : 7: Test Precision = 0.993280
# Iteration : 7: Test Recall = 0.960539
# Iteration : 7: Test F1 = 0.976635
# Iteration : 7: Fraction of allowed points in labeled dataset = 0.2857142857142857
#
# Iteration : 8: Test Accuracy = 0.992815
# Iteration : 8: Test Precision = 0.985798
# Iteration : 8: Test Recall = 1.000000
# Iteration : 8: Test F1 = 0.992848
# Iteration : 8: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 9: Test Accuracy = 0.997931
# Iteration : 9: Test Precision = 0.995919
# Iteration : 9: Test Recall = 0.999948
# Iteration : 9: Test F1 = 0.997929
# Iteration : 9: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 10: Test Accuracy = 0.993701
# Iteration : 10: Test Precision = 0.991299
# Iteration : 10: Test Recall = 0.996111
# Iteration : 10: Test F1 = 0.993699
# Iteration : 10: Fraction of allowed points in labeled dataset = 0.3
#
# Iteration : 11: Test Accuracy = 0.997735
# Iteration : 11: Test Precision = 0.996046
# Iteration : 11: Test Recall = 0.999426
# Iteration : 11: Test F1 = 0.997733
# Iteration : 11: Fraction of allowed points in labeled dataset = 0.3181818181818182
#
# Iteration : 12: Test Accuracy = 0.998178
# Iteration : 12: Test Precision = 0.996437
# Iteration : 12: Test Recall = 0.999922
# Iteration : 12: Test F1 = 0.998176
# Iteration : 12: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 13: Test Accuracy = 0.998009
# Iteration : 13: Test Precision = 0.996126
# Iteration : 13: Test Recall = 0.999896
# Iteration : 13: Test F1 = 0.998007
# Iteration : 13: Fraction of allowed points in labeled dataset = 0.34615384615384615
#
# Iteration : 14: Test Accuracy = 0.997865
# Iteration : 14: Test Precision = 0.998380
# Iteration : 14: Test Recall = 0.997338
# Iteration : 14: Test F1 = 0.997859
# Iteration : 14: Fraction of allowed points in labeled dataset = 0.32142857142857145
#
# Iteration : 15: Test Accuracy = 0.999232
# Iteration : 15: Test Precision = 0.998827
# Iteration : 15: Test Recall = 0.999635
# Iteration : 15: Test F1 = 0.999230
# Iteration : 15: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 16: Test Accuracy = 0.998751
# Iteration : 16: Test Precision = 0.997916
# Iteration : 16: Test Recall = 0.999582
# Iteration : 16: Test F1 = 0.998748
# Iteration : 16: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 17: Test Accuracy = 0.997215
# Iteration : 17: Test Precision = 0.998822
# Iteration : 17: Test Recall = 0.995589
# Iteration : 17: Test F1 = 0.997203
# Iteration : 17: Fraction of allowed points in labeled dataset = 0.35294117647058826
#
# Iteration : 18: Test Accuracy = 0.998711
# Iteration : 18: Test Precision = 0.997604
# Iteration : 18: Test Recall = 0.999817
# Iteration : 18: Test F1 = 0.998710
# Iteration : 18: Fraction of allowed points in labeled dataset = 0.3888888888888889
#
# Iteration : 19: Test Accuracy = 0.999362
# Iteration : 19: Test Precision = 0.998931
# Iteration : 19: Test Recall = 0.999791
# Iteration : 19: Test F1 = 0.999361
# Iteration : 19: Fraction of allowed points in labeled dataset = 0.3684210526315789
#
# Iteration : 20: Test Accuracy = 0.999154
# Iteration : 20: Test Precision = 0.998332
# Iteration : 20: Test Recall = 0.999974
# Iteration : 20: Test F1 = 0.999152
# Iteration : 20: Fraction of allowed points in labeled dataset = 0.4
#
# Iteration : 21: Test Accuracy = 0.999297
# Iteration : 21: Test Precision = 0.998827
# Iteration : 21: Test Recall = 0.999765
# Iteration : 21: Test F1 = 0.999296
# Iteration : 21: Fraction of allowed points in labeled dataset = 0.38095238095238093
#
# Iteration : 22: Test Accuracy = 0.999466
# Iteration : 22: Test Precision = 0.998957
# Iteration : 22: Test Recall = 0.999974
# Iteration : 22: Test F1 = 0.999465
# Iteration : 22: Fraction of allowed points in labeled dataset = 0.4090909090909091
#
# Iteration : 23: Test Accuracy = 0.999414
# Iteration : 23: Test Precision = 0.998827
# Iteration : 23: Test Recall = 1.000000
# Iteration : 23: Test F1 = 0.999413
# Iteration : 23: Fraction of allowed points in labeled dataset = 0.41304347826086957
#
# Iteration : 24: Test Accuracy = 0.999466
# Iteration : 24: Test Precision = 0.998957
# Iteration : 24: Test Recall = 0.999974
# Iteration : 24: Test F1 = 0.999465
# Iteration : 24: Fraction of allowed points in labeled dataset = 0.4166666666666667
#
# Iteration : 25: Test Accuracy = 0.999427
# Iteration : 25: Test Precision = 0.998853
# Iteration : 25: Test Recall = 1.000000
# Iteration : 25: Test F1 = 0.999426
# Iteration : 25: Fraction of allowed points in labeled dataset = 0.44
#
# Iteration : 26: Test Accuracy = 0.999414
# Iteration : 26: Test Precision = 0.998827
# Iteration : 26: Test Recall = 1.000000
# Iteration : 26: Test F1 = 0.999413
# Iteration : 26: Fraction of allowed points in labeled dataset = 0.46153846153846156
#
# Iteration : 27: Test Accuracy = 0.999440
# Iteration : 27: Test Precision = 0.998879
# Iteration : 27: Test Recall = 1.000000
# Iteration : 27: Test F1 = 0.999439
# Iteration : 27: Fraction of allowed points in labeled dataset = 0.46296296296296297
#
# Iteration : 28: Test Accuracy = 0.999518
# Iteration : 28: Test Precision = 0.999035
# Iteration : 28: Test Recall = 1.000000
# Iteration : 28: Test F1 = 0.999517
# Iteration : 28: Fraction of allowed points in labeled dataset = 0.4642857142857143
#
# Iteration : 29: Test Accuracy = 0.999479
# Iteration : 29: Test Precision = 0.998957
# Iteration : 29: Test Recall = 1.000000
# Iteration : 29: Test F1 = 0.999478
# Iteration : 29: Fraction of allowed points in labeled dataset = 0.4827586206896552
#
# Iteration : 30: Test Accuracy = 0.999492
# Iteration : 30: Test Precision = 0.998983
# Iteration : 30: Test Recall = 1.000000
# Iteration : 30: Test F1 = 0.999491
# Iteration : 30: Fraction of allowed points in labeled dataset = 0.4666666666666667
#
# Iteration : 31: Test Accuracy = 0.999453
# Iteration : 31: Test Precision = 0.998905
# Iteration : 31: Test Recall = 1.000000
# Iteration : 31: Test F1 = 0.999452
# Iteration : 31: Fraction of allowed points in labeled dataset = 0.4838709677419355
#
# Iteration : 32: Test Accuracy = 0.999479
# Iteration : 32: Test Precision = 0.998957
# Iteration : 32: Test Recall = 1.000000
# Iteration : 32: Test F1 = 0.999478
# Iteration : 32: Fraction of allowed points in labeled dataset = 0.484375
#
# Iteration : 33: Test Accuracy = 0.999557
# Iteration : 33: Test Precision = 0.999139
# Iteration : 33: Test Recall = 0.999974
# Iteration : 33: Test F1 = 0.999557
# Iteration : 33: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 34: Test Accuracy = 0.999544
# Iteration : 34: Test Precision = 0.999113
# Iteration : 34: Test Recall = 0.999974
# Iteration : 34: Test F1 = 0.999543
# Iteration : 34: Fraction of allowed points in labeled dataset = 0.5147058823529411
#
# Iteration : 35: Test Accuracy = 0.999401
# Iteration : 35: Test Precision = 0.998801
# Iteration : 35: Test Recall = 1.000000
# Iteration : 35: Test F1 = 0.999400
# Iteration : 35: Fraction of allowed points in labeled dataset = 0.5285714285714286
# Iteration : 36: Test Accuracy = 0.999479
# Iteration : 36: Test Precision = 0.998957
# Iteration : 36: Test Recall = 1.000000
# Iteration : 36: Test F1 = 0.999478
# Iteration : 36: Fraction of allowed points in labeled dataset = 0.5138888888888888
#
# Iteration : 37: Test Accuracy = 0.999505
# Iteration : 37: Test Precision = 0.999009
# Iteration : 37: Test Recall = 1.000000
# Iteration : 37: Test F1 = 0.999504
# Iteration : 37: Fraction of allowed points in labeled dataset = 0.527027027027027
#
# Iteration : 38: Test Accuracy = 0.999466
# Iteration : 38: Test Precision = 0.998931
# Iteration : 38: Test Recall = 1.000000
# Iteration : 38: Test F1 = 0.999465
# Iteration : 38: Fraction of allowed points in labeled dataset = 0.5394736842105263
#
# Iteration : 39: Test Accuracy = 0.999531
# Iteration : 39: Test Precision = 0.999087
# Iteration : 39: Test Recall = 0.999974
# Iteration : 39: Test F1 = 0.999530
# Iteration : 39: Fraction of allowed points in labeled dataset = 0.5512820512820513
#
# Iteration : 40: Test Accuracy = 0.999518
# Iteration : 40: Test Precision = 0.999035
# Iteration : 40: Test Recall = 1.000000
# Iteration : 40: Test F1 = 0.999517
# Iteration : 40: Fraction of allowed points in labeled dataset = 0.5625
#
# Final Model Test Accuracy: 0.999531
# Final Model Test Precision: 0.999087
# Final Model Test Recall: 0.999974
# Final Model Test F1: 0.999530
# Fraction of allowed points in labeled dataset: 0.573170731707317

# %%
# Plot iteration vs accuracy

plt.figure(figsize=(10, 9))

plt.subplot(2,2,1)
plt.plot(num_it_array, accuracy_array)
plt.title("Plot of iterations vs accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")

# Plot iteration vs precision

plt.subplot(2,2,2)
plt.plot(num_it_array, precision_array)
plt.title("Plot of iterations vs precision")
plt.xlabel("Iteration")
plt.ylabel("Precision")

# Plot iteration vs recall

plt.subplot(2,2,3)
plt.plot(num_it_array, recall_array)
plt.title("Plot of iterations vs recall")
plt.xlabel("Iteration")
plt.ylabel("Recall")

# Plot iteration vs f1-score

plt.subplot(2,2,4)
plt.plot(num_it_array, f1_array)
plt.title("Plot of iterations vs f1-score")
plt.xlabel("Iteration")
plt.ylabel("F1-score")
# Out:
# Text(0, 0.5, 'F1-score')
