# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from tqdm import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score
import corner
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2  # Import L2 regularization
from sklearn.preprocessing import StandardScaler
import joblib
# Out:
# 2024-02-22 12:44:44.750494: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 12:44:44.802078: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-22 12:44:44.803023: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-22 12:44:45.506976: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load and split the dataset

# %%
data = pd.read_csv('Alignment-3-Learning.csv')

# %%
data.head()
# Out:
#          mH1        mH2    mH3         mA1         mA2         mC1  \
# 0  99.975923  73.569541  125.0  166.687170  134.419471  153.336357
# 1  76.490891  84.086672  125.0  126.698795  183.771906  206.971118
# 2  91.775595  90.330741  125.0  102.245752  226.774577  335.934808
# 3  79.696642  99.892931  125.0  132.783044  138.252765  178.551539
# 4  94.306396  79.259790  125.0  151.546336  181.945070  400.559655
#
#           mC2  TanBeta1  TanBeta2  TanAlpha4  TanGamma1  TanGamma2  TanAlpha1  \
# 0  334.099897  1.193254  0.766007        0.0  18.686871  21.289641   1.193254
# 1  199.546561  1.108309  0.907853        0.0  21.637942  24.550037   1.108309
# 2  283.472389  1.434491  1.239193        0.0  15.683566  22.489833   1.434491
# 3  383.956921  0.685020  0.821585        0.0  27.304896   6.505597   0.685020
# 4  513.387669  0.995419  1.002488        0.0  15.494364   1.804920   0.995419
#
#    TanAlpha2  Output
# 0  -1.305471       1
# 1  -1.101500       1
# 2  -0.806977       1
# 3  -1.217160       1
# 4  -0.997519       1

# %%
#check for any empty cell in the database
data.isna().sum()
# Out:
# mH1          0
# mH2          0
# mH3          0
# mA1          0
# mA2          0
# mC1          0
# mC2          0
# TanBeta1     0
# TanBeta2     0
# TanAlpha4    0
# TanGamma1    0
# TanGamma2    0
# TanAlpha1    0
# TanAlpha2    0
# Output       0
# dtype: int64

# %%
#shuffle the dataframe

data_sh = data.sample(frac = 1.0, random_state = 41)

#reset the index

data_sh = data_sh.reset_index(drop=True)

# %%
#put feature variable to X and target variable to Y

X = data_sh.drop('Output', axis = 1)
Y = data_sh['Output']

# %%
# data preprocessing
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

column_names = ['mH1','mH2','mH3','mA1','mA2','mC1','mC2','TanBeta1','TanBeta2','TanAlpha4','TanGamma1','TanGamma2','TanAlpha1','TanAlpha2']

X = pd.DataFrame(X_scaled, columns=column_names)

# %%
#scaler_filename = "Alignment3-scaler.save"
#joblib.dump(scaler, scaler_filename)

# %%
#Split into train data and test data

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.915, random_state = 41)

#Split the training data further into labeled and unlabeled dataset

X_labeled, X_unlabeled, Y_labeled, Y_unlabeled = train_test_split(X_train, Y_train, test_size = 0.9997, random_state = 41)

# %%
print(f"Total Number of datapoints: {len(X)}")
print(f"Number of labeled datapoints: {len(X_labeled)}")
print(f"Number of unlabeled datapoints: {len(X_unlabeled)}")
print(f"Number of test datapoints: {len(X_test)}")
# Out:
# Total Number of datapoints: 115700
# Number of labeled datapoints: 2
# Number of unlabeled datapoints: 9832
# Number of test datapoints: 105866

# %%
frac_unlabeled = Y_unlabeled.sum()/len(Y_unlabeled)
frac_labeled = Y_labeled.sum()/len(Y_labeled)
frac_test = Y_test.sum()/len(Y_test)

# %%
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
print(f"Fraction of allowed points in unlabeled dataset: {frac_unlabeled}")
print(f"Fraction of allowed points in test dataset: {frac_test}")
# Out:
# Fraction of allowed points in labeled dataset: 0.5
# Fraction of allowed points in unlabeled dataset: 0.43561838893409277
# Fraction of allowed points in test dataset: 0.43844104811743145

# %% [markdown]
# ## Neural Network Model

# %%
# Set random seeds for reproducibility
seed_value = 41
np.random.seed(seed_value)

tf.random.set_seed(seed_value)

import random
random.seed(seed_value)

# %%
#define your model
model = keras.Sequential()

# Add input layer with 14 input parameters
model.add(layers.Input(shape=(X.shape[1],)))

model.add(layers.Dense(128, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(64, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(1, activation = 'sigmoid'))

custom_learning_rate = 0.001  

# Compile the model with a custom learning rate
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
model.compile(loss='binary_crossentropy', optimizer=custom_optimizer)

# Display the model summary to see the architecture
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 128)               1920
#
#  batch_normalization_24 (Ba  (None, 128)               512
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 128)               0
#
#  dropout_24 (Dropout)        (None, 128)               0
#
#  dense_31 (Dense)            (None, 32)                4128
#
#  batch_normalization_25 (Ba  (None, 32)                128
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 32)                0
#
#  dropout_25 (Dropout)        (None, 32)                0
#
#  dense_32 (Dense)            (None, 64)                2112
#
#  batch_normalization_26 (Ba  (None, 64)                256
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 64)                0
#
#  dropout_26 (Dropout)        (None, 64)                0
#
#  dense_33 (Dense)            (None, 32)                2080
#
#  batch_normalization_27 (Ba  (None, 32)                128
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 32)                0
#
#  dropout_27 (Dropout)        (None, 32)                0
#
#  dense_34 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 11297 (44.13 KB)
# Trainable params: 10785 (42.13 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## Active Learning Loop

# %%
#active learning loop
num_iterations = 37

num_it_array = np.arange(1,num_iterations+2,1)
accuracy_array = np.zeros(num_iterations+1)
precision_array = np.zeros(num_iterations+1)
recall_array = np.zeros(num_iterations+1)
f1_array = np.zeros(num_iterations+1)

for iteration in range(num_iterations):
    #Train the model
    model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)
    
    #Get model predictions on the test data
    Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
    #Convert the predictions into binary
    Y_pred_binary = (Y_pred_test > 0.9).astype(int)
    
    #Calculate accuracy,precision,recall and F1 Score on the test set
    accuracy = accuracy_score(Y_test, Y_pred_binary)
    accuracy_array[iteration] = accuracy
    precision = precision_score(Y_test, Y_pred_binary)
    precision_array[iteration] = precision
    recall = recall_score(Y_test, Y_pred_binary)
    recall_array[iteration] = recall
    f1 = f1_score(Y_test, Y_pred_binary)
    f1_array[iteration] = f1
    frac_labeled = Y_labeled.sum()/len(Y_labeled)
    print(f"Iteration : {iteration + 1}: Test Accuracy = {accuracy:.6f}")
    print(f"Iteration : {iteration + 1}: Test Precision = {precision:.6f}")
    print(f"Iteration : {iteration + 1}: Test Recall = {recall:.6f}")
    print(f"Iteration : {iteration + 1}: Test F1 = {f1:.6f}")
    print(f"Iteration : {iteration + 1}: Fraction of allowed points in labeled dataset = {frac_labeled}")
    print(" ") #Print a blank line
    
    #Get model predictions on the unlabeled data
    Y_pred_unlabel = model.predict(X_unlabeled, verbose=0).ravel()
    
    #Calculate entropy
    entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)
    
    #Select the most uncertain samples
    num_samples_to_label = 2
    selected_indices = np.argsort(entropy)[-num_samples_to_label:]
    
    #move the selected samples from unlabeled to labeled data
    X_labeled = pd.concat([X_labeled, X_unlabeled.iloc[selected_indices]])
    Y_labeled = pd.concat([Y_labeled, pd.Series(Y_unlabeled.iloc[selected_indices])])
    
    #Remove the newly labeled samples from the unlabeled data
    X_unlabeled = X_unlabeled.drop(X_unlabeled.index[selected_indices])
    Y_unlabeled = Y_unlabeled.drop(Y_unlabeled.index[selected_indices])
    
#Train the final model on all labeled data 
model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)

#Evaluate the final model on the test data
Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
#Convert the predictions into binary
Y_pred_binary = (Y_pred_test > 0.9).astype(int)

#Calculate various metric scores
final_accuracy = accuracy_score(Y_test, Y_pred_binary)
accuracy_array[-1] = final_accuracy
final_precision = precision_score(Y_test, Y_pred_binary)
precision_array[-1] = final_precision
final_recall = recall_score(Y_test, Y_pred_binary)
recall_array[-1] = final_recall
final_f1 = f1_score(Y_test, Y_pred_binary)
f1_array[-1] = final_f1
frac_labeled = Y_labeled.sum()/len(Y_labeled)

print(f"Final Model Test Accuracy: {final_accuracy:.6f}")
print(f"Final Model Test Precision: {final_precision:.6f}")
print(f"Final Model Test Recall: {final_recall:.6f}")
print(f"Final Model Test F1: {final_f1:.6f}")
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
# Out:
# /home/akshat/work_env/work_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration : 1: Test Accuracy = 0.561559
# Iteration : 1: Test Precision = 0.000000
# Iteration : 1: Test Recall = 0.000000
# Iteration : 1: Test F1 = 0.000000
# Iteration : 1: Fraction of allowed points in labeled dataset = 0.5
# /home/akshat/work_env/work_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration : 2: Test Accuracy = 0.561559
# Iteration : 2: Test Precision = 0.000000
# Iteration : 2: Test Recall = 0.000000
# Iteration : 2: Test F1 = 0.000000
# Iteration : 2: Fraction of allowed points in labeled dataset = 0.5
# /home/akshat/work_env/work_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration : 3: Test Accuracy = 0.561559
# Iteration : 3: Test Precision = 0.000000
# Iteration : 3: Test Recall = 0.000000
# Iteration : 3: Test F1 = 0.000000
# Iteration : 3: Fraction of allowed points in labeled dataset = 0.5
# /home/akshat/work_env/work_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration : 4: Test Accuracy = 0.561559
# Iteration : 4: Test Precision = 0.000000
# Iteration : 4: Test Recall = 0.000000
# Iteration : 4: Test F1 = 0.000000
# Iteration : 4: Fraction of allowed points in labeled dataset = 0.375
# /home/akshat/work_env/work_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration : 5: Test Accuracy = 0.561559
# Iteration : 5: Test Precision = 0.000000
# Iteration : 5: Test Recall = 0.000000
# Iteration : 5: Test F1 = 0.000000
# Iteration : 5: Fraction of allowed points in labeled dataset = 0.3
#
# Iteration : 6: Test Accuracy = 0.562900
# Iteration : 6: Test Precision = 1.000000
# Iteration : 6: Test Recall = 0.003059
# Iteration : 6: Test F1 = 0.006100
# Iteration : 6: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 7: Test Accuracy = 0.596225
# Iteration : 7: Test Precision = 1.000000
# Iteration : 7: Test Recall = 0.079068
# Iteration : 7: Test F1 = 0.146548
# Iteration : 7: Fraction of allowed points in labeled dataset = 0.2857142857142857
#
# Iteration : 8: Test Accuracy = 0.722895
# Iteration : 8: Test Precision = 1.000000
# Iteration : 8: Test Recall = 0.367977
# Iteration : 8: Test F1 = 0.537987
# Iteration : 8: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 9: Test Accuracy = 0.848752
# Iteration : 9: Test Precision = 0.999934
# Iteration : 9: Test Recall = 0.655076
# Iteration : 9: Test F1 = 0.791576
# Iteration : 9: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 10: Test Accuracy = 0.908280
# Iteration : 10: Test Precision = 0.999592
# Iteration : 10: Test Recall = 0.791128
# Iteration : 10: Test F1 = 0.883226
# Iteration : 10: Fraction of allowed points in labeled dataset = 0.35
#
# Iteration : 11: Test Accuracy = 0.931243
# Iteration : 11: Test Precision = 0.999082
# Iteration : 11: Test Recall = 0.843955
# Iteration : 11: Test F1 = 0.914990
# Iteration : 11: Fraction of allowed points in labeled dataset = 0.36363636363636365
#
# Iteration : 12: Test Accuracy = 0.984594
# Iteration : 12: Test Precision = 0.998220
# Iteration : 12: Test Recall = 0.966585
# Iteration : 12: Test F1 = 0.982148
# Iteration : 12: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 13: Test Accuracy = 0.991895
# Iteration : 13: Test Precision = 0.998076
# Iteration : 13: Test Recall = 0.983411
# Iteration : 13: Test F1 = 0.990689
# Iteration : 13: Fraction of allowed points in labeled dataset = 0.34615384615384615
#
# Iteration : 14: Test Accuracy = 0.996486
# Iteration : 14: Test Precision = 0.997838
# Iteration : 14: Test Recall = 0.994140
# Iteration : 14: Test F1 = 0.995985
# Iteration : 14: Fraction of allowed points in labeled dataset = 0.35714285714285715
#
# Iteration : 15: Test Accuracy = 0.996505
# Iteration : 15: Test Precision = 0.998010
# Iteration : 15: Test Recall = 0.994011
# Iteration : 15: Test F1 = 0.996006
# Iteration : 15: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 16: Test Accuracy = 0.998092
# Iteration : 16: Test Precision = 0.998167
# Iteration : 16: Test Recall = 0.997479
# Iteration : 16: Test F1 = 0.997823
# Iteration : 16: Fraction of allowed points in labeled dataset = 0.3125
#
# Iteration : 17: Test Accuracy = 0.836803
# Iteration : 17: Test Precision = 0.999966
# Iteration : 17: Test Recall = 0.627801
# Iteration : 17: Test F1 = 0.771338
# Iteration : 17: Fraction of allowed points in labeled dataset = 0.29411764705882354
#
# Iteration : 18: Test Accuracy = 0.622485
# Iteration : 18: Test Precision = 1.000000
# Iteration : 18: Test Recall = 0.138961
# Iteration : 18: Test F1 = 0.244013
# Iteration : 18: Fraction of allowed points in labeled dataset = 0.2777777777777778
#
# Iteration : 19: Test Accuracy = 0.603943
# Iteration : 19: Test Precision = 1.000000
# Iteration : 19: Test Recall = 0.096669
# Iteration : 19: Test F1 = 0.176296
# Iteration : 19: Fraction of allowed points in labeled dataset = 0.2631578947368421
#
# Iteration : 20: Test Accuracy = 0.623222
# Iteration : 20: Test Precision = 1.000000
# Iteration : 20: Test Recall = 0.140641
# Iteration : 20: Test F1 = 0.246600
# Iteration : 20: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 21: Test Accuracy = 0.623250
# Iteration : 21: Test Precision = 1.000000
# Iteration : 21: Test Recall = 0.140706
# Iteration : 21: Test F1 = 0.246700
# Iteration : 21: Fraction of allowed points in labeled dataset = 0.23809523809523808
#
# Iteration : 22: Test Accuracy = 0.772864
# Iteration : 22: Test Precision = 1.000000
# Iteration : 22: Test Recall = 0.481946
# Iteration : 22: Test F1 = 0.650423
# Iteration : 22: Fraction of allowed points in labeled dataset = 0.2727272727272727
#
# Iteration : 23: Test Accuracy = 0.931130
# Iteration : 23: Test Precision = 0.999872
# Iteration : 23: Test Recall = 0.843028
# Iteration : 23: Test F1 = 0.914776
# Iteration : 23: Fraction of allowed points in labeled dataset = 0.30434782608695654
#
# Iteration : 24: Test Accuracy = 0.943854
# Iteration : 24: Test Precision = 0.999901
# Iteration : 24: Test Recall = 0.872027
# Iteration : 24: Test F1 = 0.931596
# Iteration : 24: Fraction of allowed points in labeled dataset = 0.2916666666666667
#
# Iteration : 25: Test Accuracy = 0.968101
# Iteration : 25: Test Precision = 0.999907
# Iteration : 25: Test Recall = 0.927331
# Iteration : 25: Test F1 = 0.962253
# Iteration : 25: Fraction of allowed points in labeled dataset = 0.3
#
# Iteration : 26: Test Accuracy = 0.991281
# Iteration : 26: Test Precision = 0.999890
# Iteration : 26: Test Recall = 0.980222
# Iteration : 26: Test F1 = 0.989959
# Iteration : 26: Fraction of allowed points in labeled dataset = 0.3076923076923077
#
# Iteration : 27: Test Accuracy = 0.982450
# Iteration : 27: Test Precision = 0.999888
# Iteration : 27: Test Recall = 0.960078
# Iteration : 27: Test F1 = 0.979579
# Iteration : 27: Fraction of allowed points in labeled dataset = 0.3148148148148148
#
# Iteration : 28: Test Accuracy = 0.993454
# Iteration : 28: Test Precision = 0.999847
# Iteration : 28: Test Recall = 0.985221
# Iteration : 28: Test F1 = 0.992480
# Iteration : 28: Fraction of allowed points in labeled dataset = 0.32142857142857145
#
# Iteration : 29: Test Accuracy = 0.998177
# Iteration : 29: Test Precision = 0.999827
# Iteration : 29: Test Recall = 0.996014
# Iteration : 29: Test F1 = 0.997917
# Iteration : 29: Fraction of allowed points in labeled dataset = 0.3448275862068966
#
# Iteration : 30: Test Accuracy = 0.999726
# Iteration : 30: Test Precision = 0.999785
# Iteration : 30: Test Recall = 0.999591
# Iteration : 30: Test F1 = 0.999688
# Iteration : 30: Fraction of allowed points in labeled dataset = 0.36666666666666664
#
# Iteration : 31: Test Accuracy = 0.999310
# Iteration : 31: Test Precision = 0.999763
# Iteration : 31: Test Recall = 0.998664
# Iteration : 31: Test F1 = 0.999213
# Iteration : 31: Fraction of allowed points in labeled dataset = 0.3709677419354839
#
# Iteration : 32: Test Accuracy = 0.999679
# Iteration : 32: Test Precision = 0.999763
# Iteration : 32: Test Recall = 0.999504
# Iteration : 32: Test F1 = 0.999634
# Iteration : 32: Fraction of allowed points in labeled dataset = 0.390625
#
# Iteration : 33: Test Accuracy = 0.781800
# Iteration : 33: Test Precision = 1.000000
# Iteration : 33: Test Recall = 0.502327
# Iteration : 33: Test F1 = 0.668732
# Iteration : 33: Fraction of allowed points in labeled dataset = 0.4090909090909091
#
# Iteration : 34: Test Accuracy = 0.980919
# Iteration : 34: Test Precision = 0.999910
# Iteration : 34: Test Recall = 0.956567
# Iteration : 34: Test F1 = 0.977758
# Iteration : 34: Fraction of allowed points in labeled dataset = 0.4264705882352941
#
# Iteration : 35: Test Accuracy = 0.987749
# Iteration : 35: Test Precision = 0.999867
# Iteration : 35: Test Recall = 0.972186
# Iteration : 35: Test F1 = 0.985832
# Iteration : 35: Fraction of allowed points in labeled dataset = 0.4142857142857143
#
# Iteration : 36: Test Accuracy = 0.999225
# Iteration : 36: Test Precision = 0.999806
# Iteration : 36: Test Recall = 0.998427
# Iteration : 36: Test F1 = 0.999116
# Iteration : 36: Fraction of allowed points in labeled dataset = 0.4305555555555556
#
# Iteration : 37: Test Accuracy = 0.999839
# Iteration : 37: Test Precision = 0.999655
# Iteration : 37: Test Recall = 0.999978
# Iteration : 37: Test F1 = 0.999817
# Iteration : 37: Fraction of allowed points in labeled dataset = 0.44594594594594594
#
# Final Model Test Accuracy: 0.999849
# Final Model Test Precision: 0.999655
# Final Model Test Recall: 1.000000
# Final Model Test F1: 0.999828
# Fraction of allowed points in labeled dataset: 0.4605263157894737

# %%
#model.save('Alignment-3.keras')

# %%
# Plot iteration vs accuracy

plt.figure(figsize=(10, 9))

plt.subplot(2,2,1)
plt.plot(num_it_array, accuracy_array)
plt.title("Plot of iterations vs accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")

# Plot iteration vs precision

plt.subplot(2,2,2)
plt.plot(num_it_array, precision_array)
plt.title("Plot of iterations vs precision")
plt.xlabel("Iteration")
plt.ylabel("Precision")

# Plot iteration vs recall

plt.subplot(2,2,3)
plt.plot(num_it_array, recall_array)
plt.title("Plot of iterations vs recall")
plt.xlabel("Iteration")
plt.ylabel("Recall")

# Plot iteration vs f1-score

plt.subplot(2,2,4)
plt.plot(num_it_array, f1_array)
plt.title("Plot of iterations vs f1-score")
plt.xlabel("Iteration")
plt.ylabel("F1-score")

plt.tight_layout()
plt.savefig("Neural.pdf", bbox_inches = 'tight', dpi = 200, format="pdf")
