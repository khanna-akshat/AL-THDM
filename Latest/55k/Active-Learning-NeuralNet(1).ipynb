# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from tqdm import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score
import corner
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2  # Import L2 regularization
from sklearn.preprocessing import StandardScaler
# Out:
# 2023-12-05 18:21:41.655349: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-05 18:21:41.707614: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-05 18:21:41.709097: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-05 18:21:42.430754: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load and split the dataset

# %%
data = pd.read_csv('Alignment-1-Learning.csv')

# %%
data.head()
# Out:
#      mH1         mH2         mH3         mA1         mA2         mC1  \
# 0  125.0  389.681890  266.205554  357.716926  216.548541  437.974724
# 1  125.0  466.478864  389.569317  402.965051  380.172764  364.184617
# 2  125.0  220.948750  486.689377  537.099375  320.173513  243.467599
# 3  125.0  328.343580  323.472676  221.752325  348.389320  487.707855
# 4  125.0  335.247929  211.280269  206.867278  340.005918  207.546645
#
#           mC2  TanBeta1  TanBeta2  TanAlpha4  TanGamma1  TanGamma2  TanAlpha1  \
# 0  291.549211  1.825617  0.708838   5.560399  21.627008  24.836633   1.825617
# 1  381.934382  1.054113  0.609084  10.036226  20.546985  15.891286   1.054113
# 2  406.498383  1.303290  0.919230  13.261847  23.903331  21.670848   1.303290
# 3  305.971767  0.793804  0.669176  11.678012  12.508026  14.745824   0.793804
# 4  227.085078  2.043520  1.108583  16.270581  13.387200  20.521982   2.043520
#
#    TanAlpha2  Output
# 0   0.708838       1
# 1   0.609084       1
# 2   0.919230       1
# 3   0.669176       1
# 4   1.108583       1

# %%
#check for any empty cell in the database
data.isna().sum()
# Out:
# mH1          0
# mH2          0
# mH3          0
# mA1          0
# mA2          0
# mC1          0
# mC2          0
# TanBeta1     0
# TanBeta2     0
# TanAlpha4    0
# TanGamma1    0
# TanGamma2    0
# TanAlpha1    0
# TanAlpha2    0
# Output       0
# dtype: int64

# %%
#shuffle the dataframe

data_sh = data.sample(frac = 1.0, random_state = 80)

#reset the index

data_sh = data_sh.reset_index(drop=True)

# %%
#put feature variable to X and target variable to Y

X = data_sh.drop('Output', axis = 1)
Y = data_sh['Output']

# %%
# data preprocessing
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

column_names = ['mH1','mH2','mH3','mA1','mA2','mC1','mC2','TanBeta1','TanBeta2','TanAlpha4','TanGamma1','TanGamma2','TanAlpha1','TanAlpha2']

X = pd.DataFrame(X_scaled, columns=column_names)

# %%
#Split into train data and test data

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.92, random_state = 80)

#Split the training data further into labeled and unlabeled dataset

X_labeled, X_unlabeled, Y_labeled, Y_unlabeled = train_test_split(X_train, Y_train, test_size = 0.9997, random_state = 80)

# %%
print(f"Total Number of datapoints: {len(X)}")
print(f"Number of labeled datapoints: {len(X_labeled)}")
print(f"Number of unlabeled datapoints: {len(X_unlabeled)}")
print(f"Number of test datapoints: {len(X_test)}")
# Out:
# Total Number of datapoints: 106276
# Number of labeled datapoints: 2
# Number of unlabeled datapoints: 8500
# Number of test datapoints: 97774

# %%
frac_unlabeled = Y_unlabeled.sum()/len(Y_unlabeled)
frac_labeled = Y_labeled.sum()/len(Y_labeled)
frac_test = Y_test.sum()/len(Y_test)

# %%
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
print(f"Fraction of allowed points in unlabeled dataset: {frac_unlabeled}")
print(f"Fraction of allowed points in test dataset: {frac_test}")
# Out:
# Fraction of allowed points in labeled dataset: 0.5
# Fraction of allowed points in unlabeled dataset: 0.4875294117647059
# Fraction of allowed points in test dataset: 0.48204021519013235

# %% [markdown]
# ## Neural Network Model 1

# %%
# Set random seeds for reproducibility
seed_value = 80
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

import random
random.seed(seed_value)

# %%
#define your model
model = keras.Sequential()

# Add input layer with 14 input parameters
model.add(layers.Input(shape=(X.shape[1],)))

model.add(layers.Dense(128, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(64, kernel_regularizer=l2(0.001)))
model.add(layers.BatchNormalization())
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.6))

model.add(layers.Dense(1, activation = 'sigmoid'))

custom_learning_rate = 0.001  

# Compile the model with a custom learning rate
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
model.compile(loss='binary_crossentropy', optimizer=custom_optimizer)

# Display the model summary to see the architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_1 (Activation)   (None, 32)                0
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 9121 (35.63 KB)
# Trainable params: 8673 (33.88 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %% [markdown]
# ## Active Learning Loop

# %%
#active learning loop
num_iterations = 35

num_it_array = np.arange(1,num_iterations+2,1)
accuracy_array = np.zeros(num_iterations+1)
precision_array = np.zeros(num_iterations+1)
recall_array = np.zeros(num_iterations+1)
f1_array = np.zeros(num_iterations+1)

for iteration in range(num_iterations):
    #Train the model
    model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)
    
    #Get model predictions on the test data
    Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
    #Convert the predictions into binary
    Y_pred_binary = (Y_pred_test > 0.9).astype(int)
    
    #Calculate accuracy,precision,recall and F1 Score on the test set
    accuracy = accuracy_score(Y_test, Y_pred_binary)
    accuracy_array[iteration] = accuracy
    precision = precision_score(Y_test, Y_pred_binary)
    precision_array[iteration] = precision
    recall = recall_score(Y_test, Y_pred_binary)
    recall_array[iteration] = recall
    f1 = f1_score(Y_test, Y_pred_binary)
    f1_array[iteration] = f1
    frac_labeled = Y_labeled.sum()/len(Y_labeled)
    print(f"Iteration : {iteration + 1}: Test Accuracy = {accuracy:.6f}")
    print(f"Iteration : {iteration + 1}: Test Precision = {precision:.6f}")
    print(f"Iteration : {iteration + 1}: Test Recall = {recall:.6f}")
    print(f"Iteration : {iteration + 1}: Test F1 = {f1:.6f}")
    print(f"Iteration : {iteration + 1}: Fraction of allowed points in labeled dataset = {frac_labeled}")
    print(" ") #Print a blank line
    
    #Get model predictions on the unlabeled data
    Y_pred_unlabel = model.predict(X_unlabeled, verbose=0).ravel()
    
    #Calculate entropy
    entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)
    
    #Select the most uncertain samples
    num_samples_to_label = 2
    selected_indices = np.argsort(entropy)[-num_samples_to_label:]
    
    #move the selected samples from unlabeled to labeled data
    X_labeled = pd.concat([X_labeled, X_unlabeled.iloc[selected_indices]])
    Y_labeled = pd.concat([Y_labeled, pd.Series(Y_unlabeled.iloc[selected_indices])])
    
    #Remove the newly labeled samples from the unlabeled data
    X_unlabeled = X_unlabeled.drop(X_unlabeled.index[selected_indices])
    Y_unlabeled = Y_unlabeled.drop(Y_unlabeled.index[selected_indices])
    
#Train the final model on all labeled data 
model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)

#Evaluate the final model on the test data
Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
#Convert the predictions into binary
Y_pred_binary = (Y_pred_test > 0.9).astype(int)

#Calculate various metric scores
final_accuracy = accuracy_score(Y_test, Y_pred_binary)
accuracy_array[-1] = final_accuracy
final_precision = precision_score(Y_test, Y_pred_binary)
precision_array[-1] = final_precision
final_recall = recall_score(Y_test, Y_pred_binary)
recall_array[-1] = final_recall
final_f1 = f1_score(Y_test, Y_pred_binary)
f1_array[-1] = final_f1
frac_labeled = Y_labeled.sum()/len(Y_labeled)

print(f"Final Model Test Accuracy: {final_accuracy:.6f}")
print(f"Final Model Test Precision: {final_precision:.6f}")
print(f"Final Model Test Recall: {final_recall:.6f}")
print(f"Final Model Test F1: {final_f1:.6f}")
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
# Out:
# /home/akshat/work_env/work_env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Iteration : 1: Test Accuracy = 0.517960
# Iteration : 1: Test Precision = 0.000000
# Iteration : 1: Test Recall = 0.000000
# Iteration : 1: Test F1 = 0.000000
# Iteration : 1: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 2: Test Accuracy = 0.604752
# Iteration : 2: Test Precision = 0.993831
# Iteration : 2: Test Recall = 0.181176
# Iteration : 2: Test F1 = 0.306480
# Iteration : 2: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 3: Test Accuracy = 0.937570
# Iteration : 3: Test Precision = 0.993338
# Iteration : 3: Test Recall = 0.876366
# Iteration : 3: Test F1 = 0.931193
# Iteration : 3: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 4: Test Accuracy = 0.972324
# Iteration : 4: Test Precision = 0.994237
# Iteration : 4: Test Recall = 0.948081
# Iteration : 4: Test F1 = 0.970611
# Iteration : 4: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 5: Test Accuracy = 0.997106
# Iteration : 5: Test Precision = 0.997367
# Iteration : 5: Test Recall = 0.996626
# Iteration : 5: Test F1 = 0.996997
# Iteration : 5: Fraction of allowed points in labeled dataset = 0.2
#
# Iteration : 6: Test Accuracy = 0.998507
# Iteration : 6: Test Precision = 0.996912
# Iteration : 6: Test Recall = 1.000000
# Iteration : 6: Test F1 = 0.998454
# Iteration : 6: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 7: Test Accuracy = 0.998139
# Iteration : 7: Test Precision = 0.996783
# Iteration : 7: Test Recall = 0.999363
# Iteration : 7: Test F1 = 0.998072
# Iteration : 7: Fraction of allowed points in labeled dataset = 0.14285714285714285
#
# Iteration : 8: Test Accuracy = 0.997832
# Iteration : 8: Test Precision = 0.997814
# Iteration : 8: Test Recall = 0.997687
# Iteration : 8: Test F1 = 0.997751
# Iteration : 8: Fraction of allowed points in labeled dataset = 0.125
#
# Iteration : 9: Test Accuracy = 0.998179
# Iteration : 9: Test Precision = 0.997753
# Iteration : 9: Test Recall = 0.998472
# Iteration : 9: Test F1 = 0.998112
# Iteration : 9: Fraction of allowed points in labeled dataset = 0.1111111111111111
#
# Iteration : 10: Test Accuracy = 0.993321
# Iteration : 10: Test Precision = 0.997879
# Iteration : 10: Test Recall = 0.988246
# Iteration : 10: Test F1 = 0.993039
# Iteration : 10: Fraction of allowed points in labeled dataset = 0.1
#
# Iteration : 11: Test Accuracy = 0.997095
# Iteration : 11: Test Precision = 0.998298
# Iteration : 11: Test Recall = 0.995672
# Iteration : 11: Test F1 = 0.996983
# Iteration : 11: Fraction of allowed points in labeled dataset = 0.09090909090909091
#
# Iteration : 12: Test Accuracy = 0.984832
# Iteration : 12: Test Precision = 0.998645
# Iteration : 12: Test Recall = 0.969850
# Iteration : 12: Test F1 = 0.984037
# Iteration : 12: Fraction of allowed points in labeled dataset = 0.08333333333333333
#
# Iteration : 13: Test Accuracy = 0.995438
# Iteration : 13: Test Precision = 0.998761
# Iteration : 13: Test Recall = 0.991768
# Iteration : 13: Test F1 = 0.995252
# Iteration : 13: Fraction of allowed points in labeled dataset = 0.11538461538461539
#
# Iteration : 14: Test Accuracy = 0.979729
# Iteration : 14: Test Precision = 0.998873
# Iteration : 14: Test Recall = 0.959029
# Iteration : 14: Test F1 = 0.978546
# Iteration : 14: Fraction of allowed points in labeled dataset = 0.10714285714285714
#
# Iteration : 15: Test Accuracy = 0.996543
# Iteration : 15: Test Precision = 0.998615
# Iteration : 15: Test Recall = 0.994208
# Iteration : 15: Test F1 = 0.996406
# Iteration : 15: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 16: Test Accuracy = 0.994037
# Iteration : 16: Test Precision = 0.998821
# Iteration : 16: Test Recall = 0.988797
# Iteration : 16: Test F1 = 0.993784
# Iteration : 16: Fraction of allowed points in labeled dataset = 0.15625
#
# Iteration : 17: Test Accuracy = 0.979473
# Iteration : 17: Test Precision = 0.999358
# Iteration : 17: Test Recall = 0.958032
# Iteration : 17: Test F1 = 0.978259
# Iteration : 17: Fraction of allowed points in labeled dataset = 0.14705882352941177
#
# Iteration : 18: Test Accuracy = 0.750015
# Iteration : 18: Test Precision = 0.999912
# Iteration : 18: Test Recall = 0.481445
# Iteration : 18: Test F1 = 0.649948
# Iteration : 18: Fraction of allowed points in labeled dataset = 0.1388888888888889
#
# Iteration : 19: Test Accuracy = 0.835130
# Iteration : 19: Test Precision = 0.999936
# Iteration : 19: Test Recall = 0.658017
# Iteration : 19: Test F1 = 0.793719
# Iteration : 19: Fraction of allowed points in labeled dataset = 0.18421052631578946
#
# Iteration : 20: Test Accuracy = 0.977990
# Iteration : 20: Test Precision = 0.999689
# Iteration : 20: Test Recall = 0.954637
# Iteration : 20: Test F1 = 0.976644
# Iteration : 20: Fraction of allowed points in labeled dataset = 0.225
#
# Iteration : 21: Test Accuracy = 0.963712
# Iteration : 21: Test Precision = 0.999656
# Iteration : 21: Test Recall = 0.925039
# Iteration : 21: Test F1 = 0.960901
# Iteration : 21: Fraction of allowed points in labeled dataset = 0.21428571428571427
#
# Iteration : 22: Test Accuracy = 0.932661
# Iteration : 22: Test Precision = 0.999827
# Iteration : 22: Test Recall = 0.860453
# Iteration : 22: Test F1 = 0.924919
# Iteration : 22: Fraction of allowed points in labeled dataset = 0.20454545454545456
#
# Iteration : 23: Test Accuracy = 0.931260
# Iteration : 23: Test Precision = 0.999901
# Iteration : 23: Test Recall = 0.857482
# Iteration : 23: Test F1 = 0.923232
# Iteration : 23: Fraction of allowed points in labeled dataset = 0.1956521739130435
#
# Iteration : 24: Test Accuracy = 0.995735
# Iteration : 24: Test Precision = 0.999850
# Iteration : 24: Test Recall = 0.991301
# Iteration : 24: Test F1 = 0.995557
# Iteration : 24: Fraction of allowed points in labeled dataset = 0.22916666666666666
#
# Iteration : 25: Test Accuracy = 0.959273
# Iteration : 25: Test Precision = 0.999907
# Iteration : 25: Test Recall = 0.915597
# Iteration : 25: Test F1 = 0.955897
# Iteration : 25: Fraction of allowed points in labeled dataset = 0.22
#
# Iteration : 26: Test Accuracy = 0.996707
# Iteration : 26: Test Precision = 0.999765
# Iteration : 26: Test Recall = 0.993401
# Iteration : 26: Test F1 = 0.996573
# Iteration : 26: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 27: Test Accuracy = 0.999499
# Iteration : 27: Test Precision = 0.999724
# Iteration : 27: Test Recall = 0.999236
# Iteration : 27: Test F1 = 0.999480
# Iteration : 27: Fraction of allowed points in labeled dataset = 0.2777777777777778
#
# Iteration : 28: Test Accuracy = 0.999806
# Iteration : 28: Test Precision = 0.999661
# Iteration : 28: Test Recall = 0.999936
# Iteration : 28: Test F1 = 0.999798
# Iteration : 28: Fraction of allowed points in labeled dataset = 0.30357142857142855
#
# Iteration : 29: Test Accuracy = 0.999489
# Iteration : 29: Test Precision = 0.999788
# Iteration : 29: Test Recall = 0.999151
# Iteration : 29: Test F1 = 0.999469
# Iteration : 29: Fraction of allowed points in labeled dataset = 0.3103448275862069
#
# Iteration : 30: Test Accuracy = 0.999734
# Iteration : 30: Test Precision = 0.999682
# Iteration : 30: Test Recall = 0.999767
# Iteration : 30: Test F1 = 0.999724
# Iteration : 30: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 31: Test Accuracy = 0.999806
# Iteration : 31: Test Precision = 0.999597
# Iteration : 31: Test Recall = 1.000000
# Iteration : 31: Test F1 = 0.999798
# Iteration : 31: Fraction of allowed points in labeled dataset = 0.3548387096774194
#
# Iteration : 32: Test Accuracy = 0.999703
# Iteration : 32: Test Precision = 0.999639
# Iteration : 32: Test Recall = 0.999745
# Iteration : 32: Test F1 = 0.999692
# Iteration : 32: Fraction of allowed points in labeled dataset = 0.359375
#
# Iteration : 33: Test Accuracy = 0.999397
# Iteration : 33: Test Precision = 0.999809
# Iteration : 33: Test Recall = 0.998939
# Iteration : 33: Test F1 = 0.999374
# Iteration : 33: Fraction of allowed points in labeled dataset = 0.3787878787878788
#
# Iteration : 34: Test Accuracy = 0.997361
# Iteration : 34: Test Precision = 0.999936
# Iteration : 34: Test Recall = 0.994590
# Iteration : 34: Test F1 = 0.997256
# Iteration : 34: Fraction of allowed points in labeled dataset = 0.36764705882352944
#
# Iteration : 35: Test Accuracy = 0.999305
# Iteration : 35: Test Precision = 0.999894
# Iteration : 35: Test Recall = 0.998663
# Iteration : 35: Test F1 = 0.999278
# Iteration : 35: Fraction of allowed points in labeled dataset = 0.38571428571428573
# Final Model Test Accuracy: 0.999836
# Final Model Test Precision: 0.999830
# Final Model Test Recall: 0.999830
# Final Model Test F1: 0.999830
# Fraction of allowed points in labeled dataset: 0.3888888888888889

# %%
# Plot iteration vs accuracy

plt.figure(figsize=(10, 9))

plt.subplot(2,2,1)
plt.plot(num_it_array, accuracy_array)
plt.title("Plot of iterations vs accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")

# Plot iteration vs precision

plt.subplot(2,2,2)
plt.plot(num_it_array, precision_array)
plt.title("Plot of iterations vs precision")
plt.xlabel("Iteration")
plt.ylabel("Precision")

# Plot iteration vs recall

plt.subplot(2,2,3)
plt.plot(num_it_array, recall_array)
plt.title("Plot of iterations vs recall")
plt.xlabel("Iteration")
plt.ylabel("Recall")

# Plot iteration vs f1-score

plt.subplot(2,2,4)
plt.plot(num_it_array, f1_array)
plt.title("Plot of iterations vs f1-score")
plt.xlabel("Iteration")
plt.ylabel("F1-score")
# Out:
# Text(0, 0.5, 'F1-score')

# %%
#Plot the ROC curve

Y_final_pred_prob = model.predict(X_test)

fpr, tpr, thresholds = roc_curve(Y_test, Y_final_pred_prob)
# Out:
# 3056/3056 [==============================] - 2s 805us/step

# %%
plt.figure(figsize=(8, 6))
plt.scatter(fpr, tpr, label='Neural network ROC Curve')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# ## Checking the model with Live generated points

# %%
import Functions as func

# %%
#generate new datapoints :- syntax (generate(batch,seed))
points = func.generate(500000,1001)

# %%
points = points.values

# %%
#check the constraints on the the generated dataset
points_allowed, points_disallowed = func.constraints_check(points)

# %%
#create a pandas dataframe of the check dataset
column_names = ['mH1','mH2','mH3','mA1','mA2','mC1','mC2','TanBeta1','TanBeta2','TanAlpha4','TanGamma1','TanGamma2','TanAlpha1','TanAlpha2']

data_disallowed = pd.DataFrame(points_disallowed, columns=column_names)
data_allowed = pd.DataFrame(points_allowed, columns=column_names)
    
#label the dataset
data_allowed['Output'] = 1
data_disallowed['Output'] = 0
    
#merge the dataset
labeled = pd.concat([data_allowed,data_disallowed], ignore_index=True)
    
#extract the X_labeled and Y_labeled
X_new = labeled.drop('Output', axis = 1)
Y_new = labeled['Output']

# %%
X_new = scaler.transform(X_new)

# %%
import time

start_time = time.time()

#Get model predictions on the test data
Y_new_test = model.predict(X_new, verbose=0).ravel()   

end_time = time.time()

elapsed_time = end_time - start_time

print(elapsed_time)
# Out:
# 15.383782386779785

# %%
Y_new.sum()
# Out:
# 2

# %%
np.where(Y_new==1)
# Out:
# (array([0, 1]),)

# %%
#Convert the predictions into binary
Y_new_binary = (Y_new_test > 0.99).astype(int)

# %%
#Calculate accuracy,precision,recall and F1 Score on the test set
accuracy = accuracy_score(Y_new, Y_new_binary)
precision = precision_score(Y_new, Y_new_binary)
recall = recall_score(Y_new, Y_new_binary)
f1 = f1_score(Y_new, Y_new_binary)
frac_labeled = Y_new.sum()/len(Y_new)
print(f"Test Accuracy = {accuracy:.6f}")
print(f"Test Precision = {precision:.6f}")
print(f"Test Recall = {recall:.6f}")
print(f"Test F1 = {f1:.6f}")
print(f"Fraction of allowed points in new dataset = {frac_labeled}")
# Out:
# Test Accuracy = 0.999978
# Test Precision = 0.090909
# Test Recall = 0.500000
# Test F1 = 0.153846
# Fraction of allowed points in new dataset = 4e-06

# %%
Y_new_binary.sum()
# Out:
# 11

# %%
np.where(Y_new_binary==1)
# Out:
# (array([     1,  21700,  22725, 103096, 218407, 269491, 333478, 375160,
#         418928, 457027, 475141]),)

# %%
Y_new_test[0]
# Out:
# 0.99957794

# %% [markdown]
# ## Checking model with new allowed points dataset

# %%
#import the csv file containing allowed values

df1 = pd.read_csv('Alignment-1-New.csv')

# %%
len(df1)
# Out:
# 975

# %%
df1['Output'] = 1

# %%
#put feature variable to X and target variable to Y

X_new = df1.drop('Output', axis = 1)
Y_new = df1['Output']

# %%
X_new = scaler.transform(X_new)

# %%
Y_new_test = model.predict(X_new)
# Out:
# 31/31 [==============================] - 0s 1ms/step

# %%
Y_new_test
# Out:
# array([[0.9760967 ],
#        [0.9908964 ],
#        [0.99831444],
#        [0.9977351 ],
#        [0.9995128 ],
#        [0.99732673],
#        [0.98324686],
#        [0.96948403],
#        [0.99762815],
#        [0.99262345],
#        [0.9975933 ],
#        [0.9952056 ],
#        [0.99945307],
#        [0.9972352 ],
#        [0.9864471 ],
#        [0.99776524],
#        [0.99573416],
#        [0.9876884 ],
#        [0.998919  ],
#        [0.99564826],
#        [0.9979409 ],
#        [0.9987487 ],
#        [0.99958867],
#        [0.9870348 ],
#        [0.97167736],
#        [0.9964383 ],
#        [0.9992262 ],
#        [0.99617934],
#        [0.999705  ],
#        [0.9861316 ],
#        [0.9990619 ],
#        [0.99630404],
#        [0.9940811 ],
#        [0.99506325],
#        [0.9977019 ],
#        [0.9923436 ],
#        [0.9981175 ],
#        [0.9905535 ],
#        [0.9951794 ],
#        [0.9960928 ],
#        [0.99031293],
#        [0.99453604],
#        [0.99415183],
#        [0.99617416],
#        [0.99708843],
#        [0.99293995],
#        [0.99457544],
#        [0.99662286],
#        [0.99818474],
#        [0.9990323 ],
#        [0.9952875 ],
#        [0.9984224 ],
#        [0.99795324],
#        [0.99872774],
#        [0.99889755],
#        [0.9945508 ],
#        [0.99577   ],
#        [0.9973118 ],
#        [0.99945134],
#        [0.9972238 ],
#        [0.99705166],
#        [0.9963454 ],
#        [0.9996446 ],
#        [0.998646  ],
#        [0.98358077],
#        [0.9975462 ],
#        [0.99782515],
#        [0.9923949 ],
#        [0.99910253],
#        [0.99759406],
#        [0.99934334],
#        [0.99575824],
#        [0.99833095],
#        [0.99880683],
#        [0.9994323 ],
#        [0.9979332 ],
#        [0.9973566 ],
#        [0.98968965],
#        [0.9985719 ],
#        [0.998417  ],
#        [0.99301445],
#        [0.9950098 ],
#        [0.98897094],
#        [0.99963564],
#        [0.9984709 ],
#        [0.99831975],
#        [0.9982792 ],
#        [0.99796   ],
#        [0.98915774],
#        [0.9953052 ],
#        [0.99656147],
#        [0.9984256 ],
#        [0.9972679 ],
#        [0.9981424 ],
#        [0.99652785],
#        [0.98921   ],
#        [0.99715424],
#        [0.9940138 ],
#        [0.9915323 ],
#        [0.9955124 ],
#        [0.99890196],
#        [0.99307513],
#        [0.9959737 ],
#        [0.997217  ],
#        [0.9918597 ],
#        [0.99269336],
#        [0.9984446 ],
#        [0.99499434],
#        [0.9956779 ],
#        [0.9924243 ],
#        [0.99714667],
#        [0.9900453 ],
#        [0.9966759 ],
#        [0.9957778 ],
#        [0.9976489 ],
#        [0.9988516 ],
#        [0.99954605],
#        [0.99964404],
#        [0.99253005],
#        [0.99392235],
#        [0.9993224 ],
#        [0.99454784],
#        [0.9978485 ],
#        [0.9990506 ],
#        [0.99116576],
#        [0.9879147 ],
#        [0.99447685],
#        [0.9890246 ],
#        [0.9991947 ],
#        [0.9986508 ],
#        [0.9963132 ],
#        [0.997681  ],
#        [0.9939594 ],
#        [0.97897685],
#        [0.98621756],
#        [0.99623805],
#        [0.9975793 ],
#        [0.99972636],
#        [0.9957671 ],
#        [0.99416906],
#        [0.9968556 ],
#        [0.99758774],
#        [0.99330854],
#        [0.9973222 ],
#        [0.99686867]], dtype=float32)

# %%
Y_new_binary = (Y_new_test > 0.85).astype(int)

# %%
Y_new_binary.sum()
# Out:
# 975

# %%
#Calculate accuracy,precision,recall and F1 Score on the test set
accuracy = accuracy_score(Y_new, Y_new_binary)
precision = precision_score(Y_new, Y_new_binary)
recall = recall_score(Y_new, Y_new_binary)
f1 = f1_score(Y_new, Y_new_binary)
frac_labeled = Y_new.sum()/len(Y_new)
print(f"Test Accuracy = {accuracy:.6f}")
print(f"Test Precision = {precision:.6f}")
print(f"Test Recall = {recall:.6f}")
print(f"Test F1 = {f1:.6f}")
print(f"Fraction of allowed points in new dataset = {frac_labeled}")
# Out:
# Test Accuracy = 1.000000
# Test Precision = 1.000000
# Test Recall = 1.000000
# Test F1 = 1.000000
# Fraction of allowed points in new dataset = 1.0

# %% [markdown]
# ## Selecting most uncertain points from unlabeled dataset

# %%
#selecting the most uncertain indices from the first model

entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)

num_samples_to_select = 2
    
selected_indices = np.argsort(entropy)[-num_samples_to_select:]

# %%
selected_indices
# Out:
# array([8000, 2710])

# %%
np.where(Y_unlabeled.iloc[selected_indices]==1)
# Out:
# (array([0]),)

# %%
#Retrieve the selected rows for the second neural network

X_train_2 = X_unlabeled.iloc[selected_indices]
Y_train_2 = Y_unlabeled.iloc[selected_indices]

# %%
#concatenate X and Y train
combined = pd.concat([X_train_2, Y_train_2],axis=1)

# %%
#Iterate over each row in X_train_2 and Y_train_2 and find the indices
indices_to_remove = []
for index, row in X_train_2.iterrows():
    indices_to_remove.extend(combined[combined[X.columns].eq(row.to_dict()).all(1)].index)

# %%
indices_to_remove
# Out:
# [35078, 15514]

# %%
#drop these indices in the total dataset
X = X.drop(indices_to_remove)
Y = Y.drop(indices_to_remove)

# %%
#Split into train data and test data

X_unlabeled, X_test, Y_unlabeled, Y_test = train_test_split(X, Y, test_size = 0.92, random_state = 42)

X_labeled = X_train_2
Y_labeled = Y_train_2

# %%
print(f"Total Number of datapoints: {len(X)}")
print(f"Number of labeled datapoints: {len(X_labeled)}")
print(f"Number of unlabeled datapoints: {len(X_unlabeled)}")
print(f"Number of test datapoints: {len(X_test)}")
# Out:
# Total Number of datapoints: 102573
# Number of labeled datapoints: 2
# Number of unlabeled datapoints: 8205
# Number of test datapoints: 94368

# %%
frac_unlabeled = Y_unlabeled.sum()/len(Y_unlabeled)
frac_labeled = Y_labeled.sum()/len(Y_labeled)
frac_test = Y_test.sum()/len(Y_test)

# %%
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
print(f"Fraction of allowed points in unlabeled dataset: {frac_unlabeled}")
print(f"Fraction of allowed points in test dataset: {frac_test}")
# Out:
# Fraction of allowed points in labeled dataset: 0.5
# Fraction of allowed points in unlabeled dataset: 0.493235831809872
# Fraction of allowed points in test dataset: 0.5004662597490674

# %% [markdown]
# ## Neural Network Model 2

# %%
# Set random seeds for reproducibility
seed_value = 42
tf.random.set_seed(seed_value)
np.random.seed(seed_value)

# %%
#define your model
model_2 = keras.Sequential()

# Add input layer with 14 input parameters
model_2.add(layers.Input(shape=(X.shape[1],)))

model_2.add(layers.Dense(128, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(64, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
model_2.add(layers.BatchNormalization())
model_2.add(layers.Activation('relu'))
model_2.add(layers.Dropout(0.6))

model_2.add(layers.Dense(1, activation = 'sigmoid'))

custom_learning_rate = 0.001  # You can adjust this value as needed

# Compile the model with a custom learning rate
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
model_2.compile(loss='binary_crossentropy', optimizer=custom_optimizer)

# Display the model summary to see the architecture
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               1920
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 32)                4128
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_6 (Dense)             (None, 64)                2112
#
#  batch_normalization_5 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64)                0
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 32)                2080
#
#  batch_normalization_6 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_6 (Activation)   (None, 32)                0
#
#  dropout_6 (Dropout)         (None, 32)                0
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 11297 (44.13 KB)
# Trainable params: 10785 (42.13 KB)
# Non-trainable params: 512 (2.00 KB)
# _________________________________________________________________

# %% [markdown]
# ## Active Learning Loop

# %%
#active learning loop
num_iterations = 40

num_it_array = np.arange(1,num_iterations+2,1)
accuracy_array = np.zeros(num_iterations+1)
precision_array = np.zeros(num_iterations+1)
recall_array = np.zeros(num_iterations+1)
f1_array = np.zeros(num_iterations+1)

for iteration in range(num_iterations):
    #Train the model
    model_2.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)
    
    #Get model predictions on the test data
    Y_pred_test = model_2.predict(X_test, verbose=0).ravel()   
    
    #Convert the predictions into binary
    Y_pred_binary = (Y_pred_test > 0.5).astype(int)
    
    #Calculate accuracy,precision,recall and F1 Score on the test set
    accuracy = accuracy_score(Y_test, Y_pred_binary)
    accuracy_array[iteration] = accuracy
    precision = precision_score(Y_test, Y_pred_binary)
    precision_array[iteration] = precision
    recall = recall_score(Y_test, Y_pred_binary)
    recall_array[iteration] = recall
    f1 = f1_score(Y_test, Y_pred_binary)
    f1_array[iteration] = f1
    frac_labeled = Y_labeled.sum()/len(Y_labeled)
    print(f"Iteration : {iteration + 1}: Test Accuracy = {accuracy:.6f}")
    print(f"Iteration : {iteration + 1}: Test Precision = {precision:.6f}")
    print(f"Iteration : {iteration + 1}: Test Recall = {recall:.6f}")
    print(f"Iteration : {iteration + 1}: Test F1 = {f1:.6f}")
    print(f"Iteration : {iteration + 1}: Fraction of allowed points in labeled dataset = {frac_labeled}")
    print(" ") #Print a blank line
    
    #Get model predictions on the unlabeled data
    Y_pred_unlabel = model_2.predict(X_unlabeled, verbose=0).ravel()
    
    #Calculate entropy
    entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)
    
    #Select the most uncertain samples
    num_samples_to_label = 2
    selected_indices = np.argsort(entropy)[-num_samples_to_label:]
    
    #move the selected samples from unlabeled to labeled data
    X_labeled = pd.concat([X_labeled, X_unlabeled.iloc[selected_indices]])
    Y_labeled = pd.concat([Y_labeled, pd.Series(Y_unlabeled.iloc[selected_indices])])
    
    #Remove the newly labeled samples from the unlabeled data
    X_unlabeled = X_unlabeled.drop(X_unlabeled.index[selected_indices])
    Y_unlabeled = Y_unlabeled.drop(Y_unlabeled.index[selected_indices])
    
#Train the final model on all labeled data 
model_2.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)

#Evaluate the final model on the test data
Y_pred_test = model_2.predict(X_test, verbose=0).ravel()   
    
#Convert the predictions into binary
Y_pred_binary = (Y_pred_test > 0.5).astype(int)

#Calculate various metric scores
final_accuracy = accuracy_score(Y_test, Y_pred_binary)
accuracy_array[-1] = final_accuracy
final_precision = precision_score(Y_test, Y_pred_binary)
precision_array[-1] = final_precision
final_recall = recall_score(Y_test, Y_pred_binary)
recall_array[-1] = final_recall
final_f1 = f1_score(Y_test, Y_pred_binary)
f1_array[-1] = final_f1
frac_labeled = Y_labeled.sum()/len(Y_labeled)

print(f"Final Model Test Accuracy: {final_accuracy:.6f}")
print(f"Final Model Test Precision: {final_precision:.6f}")
print(f"Final Model Test Recall: {final_recall:.6f}")
print(f"Final Model Test F1: {final_f1:.6f}")
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
# Out:
# Iteration : 1: Test Accuracy = 0.716482
# Iteration : 1: Test Precision = 0.641723
# Iteration : 1: Test Recall = 0.981431
# Iteration : 1: Test F1 = 0.776028
# Iteration : 1: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 2: Test Accuracy = 0.732833
# Iteration : 2: Test Precision = 0.825565
# Iteration : 2: Test Recall = 0.591048
# Iteration : 2: Test F1 = 0.688894
# Iteration : 2: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 3: Test Accuracy = 0.879981
# Iteration : 3: Test Precision = 0.895640
# Iteration : 3: Test Recall = 0.860443
# Iteration : 3: Test F1 = 0.877689
# Iteration : 3: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 4: Test Accuracy = 0.923014
# Iteration : 4: Test Precision = 0.867300
# Iteration : 4: Test Recall = 0.999026
# Iteration : 4: Test F1 = 0.928514
# Iteration : 4: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 5: Test Accuracy = 0.949051
# Iteration : 5: Test Precision = 0.907602
# Iteration : 5: Test Recall = 1.000000
# Iteration : 5: Test F1 = 0.951564
# Iteration : 5: Fraction of allowed points in labeled dataset = 0.4
#
# Iteration : 6: Test Accuracy = 0.965666
# Iteration : 6: Test Precision = 0.935801
# Iteration : 6: Test Recall = 1.000000
# Iteration : 6: Test F1 = 0.966836
# Iteration : 6: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 7: Test Accuracy = 0.987559
# Iteration : 7: Test Precision = 0.975745
# Iteration : 7: Test Recall = 1.000000
# Iteration : 7: Test F1 = 0.987724
# Iteration : 7: Fraction of allowed points in labeled dataset = 0.2857142857142857
#
# Iteration : 8: Test Accuracy = 0.993695
# Iteration : 8: Test Precision = 0.987558
# Iteration : 8: Test Recall = 1.000000
# Iteration : 8: Test F1 = 0.993740
# Iteration : 8: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 9: Test Accuracy = 0.995888
# Iteration : 9: Test Precision = 0.991851
# Iteration : 9: Test Recall = 1.000000
# Iteration : 9: Test F1 = 0.995909
# Iteration : 9: Fraction of allowed points in labeled dataset = 0.2222222222222222
#
# Iteration : 10: Test Accuracy = 0.997202
# Iteration : 10: Test Precision = 0.994441
# Iteration : 10: Test Recall = 1.000000
# Iteration : 10: Test F1 = 0.997213
# Iteration : 10: Fraction of allowed points in labeled dataset = 0.2
#
# Iteration : 11: Test Accuracy = 0.998146
# Iteration : 11: Test Precision = 0.996308
# Iteration : 11: Test Recall = 1.000000
# Iteration : 11: Test F1 = 0.998151
# Iteration : 11: Fraction of allowed points in labeled dataset = 0.18181818181818182
#
# Iteration : 12: Test Accuracy = 0.998177
# Iteration : 12: Test Precision = 0.996392
# Iteration : 12: Test Recall = 0.999979
# Iteration : 12: Test F1 = 0.998182
# Iteration : 12: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 13: Test Accuracy = 0.998103
# Iteration : 13: Test Precision = 0.996224
# Iteration : 13: Test Recall = 1.000000
# Iteration : 13: Test F1 = 0.998109
# Iteration : 13: Fraction of allowed points in labeled dataset = 0.19230769230769232
#
# Iteration : 14: Test Accuracy = 0.998093
# Iteration : 14: Test Precision = 0.996371
# Iteration : 14: Test Recall = 0.999831
# Iteration : 14: Test F1 = 0.998098
# Iteration : 14: Fraction of allowed points in labeled dataset = 0.17857142857142858
#
# Iteration : 15: Test Accuracy = 0.998463
# Iteration : 15: Test Precision = 0.996939
# Iteration : 15: Test Recall = 1.000000
# Iteration : 15: Test F1 = 0.998467
# Iteration : 15: Fraction of allowed points in labeled dataset = 0.2
#
# Iteration : 16: Test Accuracy = 0.998665
# Iteration : 16: Test Precision = 0.997339
# Iteration : 16: Test Recall = 1.000000
# Iteration : 16: Test F1 = 0.998668
# Iteration : 16: Fraction of allowed points in labeled dataset = 0.21875
#
# Iteration : 17: Test Accuracy = 0.998771
# Iteration : 17: Test Precision = 0.997592
# Iteration : 17: Test Recall = 0.999958
# Iteration : 17: Test F1 = 0.998773
# Iteration : 17: Fraction of allowed points in labeled dataset = 0.20588235294117646
#
# Iteration : 18: Test Accuracy = 0.999216
# Iteration : 18: Test Precision = 0.998625
# Iteration : 18: Test Recall = 0.999809
# Iteration : 18: Test F1 = 0.999217
# Iteration : 18: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 19: Test Accuracy = 0.999322
# Iteration : 19: Test Precision = 0.998647
# Iteration : 19: Test Recall = 1.000000
# Iteration : 19: Test F1 = 0.999323
# Iteration : 19: Fraction of allowed points in labeled dataset = 0.2631578947368421
#
# Iteration : 20: Test Accuracy = 0.999375
# Iteration : 20: Test Precision = 0.998837
# Iteration : 20: Test Recall = 0.999915
# Iteration : 20: Test F1 = 0.999376
# Iteration : 20: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 21: Test Accuracy = 0.999311
# Iteration : 21: Test Precision = 0.998900
# Iteration : 21: Test Recall = 0.999725
# Iteration : 21: Test F1 = 0.999312
# Iteration : 21: Fraction of allowed points in labeled dataset = 0.2619047619047619
#
# Iteration : 22: Test Accuracy = 0.999396
# Iteration : 22: Test Precision = 0.998795
# Iteration : 22: Test Recall = 1.000000
# Iteration : 22: Test F1 = 0.999397
# Iteration : 22: Fraction of allowed points in labeled dataset = 0.29545454545454547
#
# Iteration : 23: Test Accuracy = 0.999375
# Iteration : 23: Test Precision = 0.998773
# Iteration : 23: Test Recall = 0.999979
# Iteration : 23: Test F1 = 0.999376
# Iteration : 23: Fraction of allowed points in labeled dataset = 0.2826086956521739
#
# Iteration : 24: Test Accuracy = 0.999385
# Iteration : 24: Test Precision = 0.998773
# Iteration : 24: Test Recall = 1.000000
# Iteration : 24: Test F1 = 0.999386
# Iteration : 24: Fraction of allowed points in labeled dataset = 0.3125
#
# Iteration : 25: Test Accuracy = 0.999449
# Iteration : 25: Test Precision = 0.998900
# Iteration : 25: Test Recall = 1.000000
# Iteration : 25: Test F1 = 0.999450
# Iteration : 25: Fraction of allowed points in labeled dataset = 0.32
#
# Iteration : 26: Test Accuracy = 0.999375
# Iteration : 26: Test Precision = 0.998752
# Iteration : 26: Test Recall = 1.000000
# Iteration : 26: Test F1 = 0.999376
# Iteration : 26: Fraction of allowed points in labeled dataset = 0.34615384615384615
#
# Iteration : 27: Test Accuracy = 0.999470
# Iteration : 27: Test Precision = 0.998942
# Iteration : 27: Test Recall = 1.000000
# Iteration : 27: Test F1 = 0.999471
# Iteration : 27: Fraction of allowed points in labeled dataset = 0.37037037037037035
#
# Iteration : 28: Test Accuracy = 0.999481
# Iteration : 28: Test Precision = 0.998964
# Iteration : 28: Test Recall = 1.000000
# Iteration : 28: Test F1 = 0.999482
# Iteration : 28: Fraction of allowed points in labeled dataset = 0.39285714285714285
#
# Iteration : 29: Test Accuracy = 0.999396
# Iteration : 29: Test Precision = 0.998795
# Iteration : 29: Test Recall = 1.000000
# Iteration : 29: Test F1 = 0.999397
# Iteration : 29: Fraction of allowed points in labeled dataset = 0.41379310344827586
#
# Iteration : 30: Test Accuracy = 0.999619
# Iteration : 30: Test Precision = 0.999238
# Iteration : 30: Test Recall = 1.000000
# Iteration : 30: Test F1 = 0.999619
# Iteration : 30: Fraction of allowed points in labeled dataset = 0.4
#
# Iteration : 31: Test Accuracy = 0.999608
# Iteration : 31: Test Precision = 0.999217
# Iteration : 31: Test Recall = 1.000000
# Iteration : 31: Test F1 = 0.999608
# Iteration : 31: Fraction of allowed points in labeled dataset = 0.41935483870967744
#
# Iteration : 32: Test Accuracy = 0.999640
# Iteration : 32: Test Precision = 0.999281
# Iteration : 32: Test Recall = 1.000000
# Iteration : 32: Test F1 = 0.999640
# Iteration : 32: Fraction of allowed points in labeled dataset = 0.4375
#
# Iteration : 33: Test Accuracy = 0.999640
# Iteration : 33: Test Precision = 0.999281
# Iteration : 33: Test Recall = 1.000000
# Iteration : 33: Test F1 = 0.999640
# Iteration : 33: Fraction of allowed points in labeled dataset = 0.42424242424242425
#
# Iteration : 34: Test Accuracy = 0.999523
# Iteration : 34: Test Precision = 0.999048
# Iteration : 34: Test Recall = 1.000000
# Iteration : 34: Test F1 = 0.999524
# Iteration : 34: Fraction of allowed points in labeled dataset = 0.4411764705882353
#
# Iteration : 35: Test Accuracy = 0.999661
# Iteration : 35: Test Precision = 0.999323
# Iteration : 35: Test Recall = 1.000000
# Iteration : 35: Test F1 = 0.999661
# Iteration : 35: Fraction of allowed points in labeled dataset = 0.45714285714285713
# Iteration : 36: Test Accuracy = 0.999629
# Iteration : 36: Test Precision = 0.999259
# Iteration : 36: Test Recall = 1.000000
# Iteration : 36: Test F1 = 0.999630
# Iteration : 36: Fraction of allowed points in labeled dataset = 0.4444444444444444
#
# Iteration : 37: Test Accuracy = 0.999746
# Iteration : 37: Test Precision = 0.999492
# Iteration : 37: Test Recall = 1.000000
# Iteration : 37: Test F1 = 0.999746
# Iteration : 37: Fraction of allowed points in labeled dataset = 0.43243243243243246
#
# Iteration : 38: Test Accuracy = 0.999661
# Iteration : 38: Test Precision = 0.999323
# Iteration : 38: Test Recall = 1.000000
# Iteration : 38: Test F1 = 0.999661
# Iteration : 38: Fraction of allowed points in labeled dataset = 0.4473684210526316
#
# Iteration : 39: Test Accuracy = 0.999746
# Iteration : 39: Test Precision = 0.999492
# Iteration : 39: Test Recall = 1.000000
# Iteration : 39: Test F1 = 0.999746
# Iteration : 39: Fraction of allowed points in labeled dataset = 0.46153846153846156
#
# Iteration : 40: Test Accuracy = 0.999756
# Iteration : 40: Test Precision = 0.999513
# Iteration : 40: Test Recall = 1.000000
# Iteration : 40: Test F1 = 0.999757
# Iteration : 40: Fraction of allowed points in labeled dataset = 0.4625
#
# Final Model Test Accuracy: 0.999640
# Final Model Test Precision: 0.999281
# Final Model Test Recall: 1.000000
# Final Model Test F1: 0.999640
# Fraction of allowed points in labeled dataset: 0.45121951219512196

# %%
# Plot iteration vs accuracy

plt.figure(figsize=(10, 9))

plt.subplot(2,2,1)
plt.plot(num_it_array, accuracy_array)
plt.title("Plot of iterations vs accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")

# Plot iteration vs precision

plt.subplot(2,2,2)
plt.plot(num_it_array, precision_array)
plt.title("Plot of iterations vs precision")
plt.xlabel("Iteration")
plt.ylabel("Precision")

# Plot iteration vs recall

plt.subplot(2,2,3)
plt.plot(num_it_array, recall_array)
plt.title("Plot of iterations vs recall")
plt.xlabel("Iteration")
plt.ylabel("Recall")

# Plot iteration vs f1-score

plt.subplot(2,2,4)
plt.plot(num_it_array, f1_array)
plt.title("Plot of iterations vs f1-score")
plt.xlabel("Iteration")
plt.ylabel("F1-score")
# Out:
# Text(0, 0.5, 'F1-score')

# %% [markdown]
# ## Using Sinc Activation Function

# %%
def sinc_activation(x):
    return tf.where(tf.equal(x, 0), tf.ones_like(x), tf.sin(x) / x)

# %%
#define your model
model = keras.Sequential()

# Add input layer with 14 input parameters
model.add(layers.Input(shape=(X.shape[1],)))

model.add(layers.Dense(128, kernel_regularizer=l2(0.001)))
#model.add(layers.BatchNormalization())
model.add(layers.Activation(sinc_activation))
#model.add(layers.Dropout(0.5))

model.add(layers.Dense(32, kernel_regularizer=l2(0.001)))
#model.add(layers.BatchNormalization())
model.add(layers.Activation(sinc_activation))
#model.add(layers.Dropout(0.5))

model.add(layers.Dense(64, kernel_regularizer=l2(0.001)))
#model.add(layers.BatchNormalization())
model.add(layers.Activation(sinc_activation))
#model.add(layers.Dropout(0.5))

model.add(layers.Dense(1, activation = 'sigmoid'))

custom_learning_rate = 0.001  # You can adjust this value as needed

# Compile the model with a custom learning rate
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=custom_learning_rate)
model.compile(loss='binary_crossentropy', optimizer=custom_optimizer)

# Display the model summary to see the architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  activation (Activation)     (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  activation_1 (Activation)   (None, 32)                0
#
#  dense_2 (Dense)             (None, 64)                2112
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 8225 (32.13 KB)
# Trainable params: 8225 (32.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#active learning loop
num_iterations = 40

num_it_array = np.arange(1,num_iterations+2,1)
accuracy_array = np.zeros(num_iterations+1)
precision_array = np.zeros(num_iterations+1)
recall_array = np.zeros(num_iterations+1)
f1_array = np.zeros(num_iterations+1)

for iteration in range(num_iterations):
    #Train the model
    model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)
    
    #Get model predictions on the test data
    Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
    #Convert the predictions into binary
    Y_pred_binary = (Y_pred_test > 0.5).astype(int)
    
    #Calculate accuracy,precision,recall and F1 Score on the test set
    accuracy = accuracy_score(Y_test, Y_pred_binary)
    accuracy_array[iteration] = accuracy
    precision = precision_score(Y_test, Y_pred_binary)
    precision_array[iteration] = precision
    recall = recall_score(Y_test, Y_pred_binary)
    recall_array[iteration] = recall
    f1 = f1_score(Y_test, Y_pred_binary)
    f1_array[iteration] = f1
    frac_labeled = Y_labeled.sum()/len(Y_labeled)
    print(f"Iteration : {iteration + 1}: Test Accuracy = {accuracy:.6f}")
    print(f"Iteration : {iteration + 1}: Test Precision = {precision:.6f}")
    print(f"Iteration : {iteration + 1}: Test Recall = {recall:.6f}")
    print(f"Iteration : {iteration + 1}: Test F1 = {f1:.6f}")
    print(f"Iteration : {iteration + 1}: Fraction of allowed points in labeled dataset = {frac_labeled}")
    print(" ") #Print a blank line
    
    #Get model predictions on the unlabeled data
    Y_pred_unlabel = model.predict(X_unlabeled, verbose=0).ravel()
    
    #Calculate entropy
    entropy = -Y_pred_unlabel*np.log2(Y_pred_unlabel+1e-30) - (1-Y_pred_unlabel)*np.log2(1-Y_pred_unlabel+1e-30)
    
    #Select the most uncertain samples
    num_samples_to_label = 2
    selected_indices = np.argsort(entropy)[-num_samples_to_label:]
    
    #move the selected samples from unlabeled to labeled data
    X_labeled = pd.concat([X_labeled, X_unlabeled.iloc[selected_indices]])
    Y_labeled = pd.concat([Y_labeled, pd.Series(Y_unlabeled.iloc[selected_indices])])
    
    #Remove the newly labeled samples from the unlabeled data
    X_unlabeled = X_unlabeled.drop(X_unlabeled.index[selected_indices])
    Y_unlabeled = Y_unlabeled.drop(Y_unlabeled.index[selected_indices])
    
#Train the final model on all labeled data 
model.fit(X_labeled,Y_labeled, epochs=150, batch_size=32, verbose=0)

#Evaluate the final model on the test data
Y_pred_test = model.predict(X_test, verbose=0).ravel()   
    
#Convert the predictions into binary
Y_pred_binary = (Y_pred_test > 0.5).astype(int)

#Calculate various metric scores
final_accuracy = accuracy_score(Y_test, Y_pred_binary)
accuracy_array[-1] = final_accuracy
final_precision = precision_score(Y_test, Y_pred_binary)
precision_array[-1] = final_precision
final_recall = recall_score(Y_test, Y_pred_binary)
recall_array[-1] = final_recall
final_f1 = f1_score(Y_test, Y_pred_binary)
f1_array[-1] = final_f1
frac_labeled = Y_labeled.sum()/len(Y_labeled)

print(f"Final Model Test Accuracy: {final_accuracy:.6f}")
print(f"Final Model Test Precision: {final_precision:.6f}")
print(f"Final Model Test Recall: {final_recall:.6f}")
print(f"Final Model Test F1: {final_f1:.6f}")
print(f"Fraction of allowed points in labeled dataset: {frac_labeled}")
# Out:
# Iteration : 1: Test Accuracy = 0.511333
# Iteration : 1: Test Precision = 0.505607
# Iteration : 1: Test Recall = 1.000000
# Iteration : 1: Test F1 = 0.671632
# Iteration : 1: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 2: Test Accuracy = 0.611832
# Iteration : 2: Test Precision = 0.562834
# Iteration : 2: Test Recall = 1.000000
# Iteration : 2: Test F1 = 0.720274
# Iteration : 2: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 3: Test Accuracy = 0.804459
# Iteration : 3: Test Precision = 0.728939
# Iteration : 3: Test Recall = 0.969085
# Iteration : 3: Test F1 = 0.832030
# Iteration : 3: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 4: Test Accuracy = 0.819761
# Iteration : 4: Test Precision = 0.734946
# Iteration : 4: Test Recall = 0.999979
# Iteration : 4: Test F1 = 0.847219
# Iteration : 4: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 5: Test Accuracy = 0.985451
# Iteration : 5: Test Precision = 0.971847
# Iteration : 5: Test Recall = 0.999852
# Iteration : 5: Test F1 = 0.985650
# Iteration : 5: Fraction of allowed points in labeled dataset = 0.2
#
# Iteration : 6: Test Accuracy = 0.948415
# Iteration : 6: Test Precision = 0.998938
# Iteration : 6: Test Recall = 0.897733
# Iteration : 6: Test F1 = 0.945636
# Iteration : 6: Fraction of allowed points in labeled dataset = 0.16666666666666666
#
# Iteration : 7: Test Accuracy = 0.997351
# Iteration : 7: Test Precision = 0.994727
# Iteration : 7: Test Recall = 1.000000
# Iteration : 7: Test F1 = 0.997357
# Iteration : 7: Fraction of allowed points in labeled dataset = 0.2857142857142857
#
# Iteration : 8: Test Accuracy = 0.995592
# Iteration : 8: Test Precision = 0.998273
# Iteration : 8: Test Recall = 0.992897
# Iteration : 8: Test F1 = 0.995578
# Iteration : 8: Fraction of allowed points in labeled dataset = 0.25
#
# Iteration : 9: Test Accuracy = 0.998485
# Iteration : 9: Test Precision = 0.996977
# Iteration : 9: Test Recall = 1.000000
# Iteration : 9: Test F1 = 0.998486
# Iteration : 9: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 10: Test Accuracy = 0.998856
# Iteration : 10: Test Precision = 0.998052
# Iteration : 10: Test Recall = 0.999661
# Iteration : 10: Test F1 = 0.998856
# Iteration : 10: Fraction of allowed points in labeled dataset = 0.3
#
# Iteration : 11: Test Accuracy = 0.995369
# Iteration : 11: Test Precision = 0.998251
# Iteration : 11: Test Recall = 0.992473
# Iteration : 11: Test F1 = 0.995353
# Iteration : 11: Fraction of allowed points in labeled dataset = 0.2727272727272727
#
# Iteration : 12: Test Accuracy = 0.998400
# Iteration : 12: Test Precision = 0.996871
# Iteration : 12: Test Recall = 0.999936
# Iteration : 12: Test F1 = 0.998402
# Iteration : 12: Fraction of allowed points in labeled dataset = 0.3333333333333333
#
# Iteration : 13: Test Accuracy = 0.999354
# Iteration : 13: Test Precision = 0.998856
# Iteration : 13: Test Recall = 0.999852
# Iteration : 13: Test F1 = 0.999354
# Iteration : 13: Fraction of allowed points in labeled dataset = 0.3076923076923077
#
# Iteration : 14: Test Accuracy = 0.998898
# Iteration : 14: Test Precision = 0.998728
# Iteration : 14: Test Recall = 0.999067
# Iteration : 14: Test F1 = 0.998898
# Iteration : 14: Fraction of allowed points in labeled dataset = 0.32142857142857145
#
# Iteration : 15: Test Accuracy = 0.998993
# Iteration : 15: Test Precision = 0.998011
# Iteration : 15: Test Recall = 0.999979
# Iteration : 15: Test F1 = 0.998994
# Iteration : 15: Fraction of allowed points in labeled dataset = 0.36666666666666664
#
# Iteration : 16: Test Accuracy = 0.999523
# Iteration : 16: Test Precision = 0.999068
# Iteration : 16: Test Recall = 0.999979
# Iteration : 16: Test F1 = 0.999523
# Iteration : 16: Fraction of allowed points in labeled dataset = 0.34375
#
# Iteration : 17: Test Accuracy = 0.998866
# Iteration : 17: Test Precision = 0.999406
# Iteration : 17: Test Recall = 0.998325
# Iteration : 17: Test F1 = 0.998865
# Iteration : 17: Fraction of allowed points in labeled dataset = 0.3235294117647059
#
# Iteration : 18: Test Accuracy = 0.999449
# Iteration : 18: Test Precision = 0.998899
# Iteration : 18: Test Recall = 1.000000
# Iteration : 18: Test F1 = 0.999449
# Iteration : 18: Fraction of allowed points in labeled dataset = 0.3611111111111111
#
# Iteration : 19: Test Accuracy = 0.999650
# Iteration : 19: Test Precision = 0.999385
# Iteration : 19: Test Recall = 0.999915
# Iteration : 19: Test F1 = 0.999650
# Iteration : 19: Fraction of allowed points in labeled dataset = 0.34210526315789475
#
# Iteration : 20: Test Accuracy = 0.999693
# Iteration : 20: Test Precision = 0.999385
# Iteration : 20: Test Recall = 1.000000
# Iteration : 20: Test F1 = 0.999693
# Iteration : 20: Fraction of allowed points in labeled dataset = 0.375
#
# Iteration : 21: Test Accuracy = 0.999449
# Iteration : 21: Test Precision = 0.998983
# Iteration : 21: Test Recall = 0.999915
# Iteration : 21: Test F1 = 0.999449
# Iteration : 21: Fraction of allowed points in labeled dataset = 0.38095238095238093
#
# Iteration : 22: Test Accuracy = 0.999597
# Iteration : 22: Test Precision = 0.999216
# Iteration : 22: Test Recall = 0.999979
# Iteration : 22: Test F1 = 0.999597
# Iteration : 22: Fraction of allowed points in labeled dataset = 0.38636363636363635
#
# Iteration : 23: Test Accuracy = 0.999619
# Iteration : 23: Test Precision = 0.999258
# Iteration : 23: Test Recall = 0.999979
# Iteration : 23: Test F1 = 0.999618
# Iteration : 23: Fraction of allowed points in labeled dataset = 0.391304347826087
#
# Iteration : 24: Test Accuracy = 0.999682
# Iteration : 24: Test Precision = 0.999385
# Iteration : 24: Test Recall = 0.999979
# Iteration : 24: Test F1 = 0.999682
# Iteration : 24: Fraction of allowed points in labeled dataset = 0.4166666666666667
#
# Iteration : 25: Test Accuracy = 0.999587
# Iteration : 25: Test Precision = 0.999195
# Iteration : 25: Test Recall = 0.999979
# Iteration : 25: Test F1 = 0.999587
# Iteration : 25: Fraction of allowed points in labeled dataset = 0.44
#
# Iteration : 26: Test Accuracy = 0.999608
# Iteration : 26: Test Precision = 0.999237
# Iteration : 26: Test Recall = 0.999979
# Iteration : 26: Test F1 = 0.999608
# Iteration : 26: Fraction of allowed points in labeled dataset = 0.46153846153846156
#
# Iteration : 27: Test Accuracy = 0.999608
# Iteration : 27: Test Precision = 0.999237
# Iteration : 27: Test Recall = 0.999979
# Iteration : 27: Test F1 = 0.999608
# Iteration : 27: Fraction of allowed points in labeled dataset = 0.48148148148148145
#
# Iteration : 28: Test Accuracy = 0.999608
# Iteration : 28: Test Precision = 0.999216
# Iteration : 28: Test Recall = 1.000000
# Iteration : 28: Test F1 = 0.999608
# Iteration : 28: Fraction of allowed points in labeled dataset = 0.5
#
# Iteration : 29: Test Accuracy = 0.999587
# Iteration : 29: Test Precision = 0.999174
# Iteration : 29: Test Recall = 1.000000
# Iteration : 29: Test F1 = 0.999587
# Iteration : 29: Fraction of allowed points in labeled dataset = 0.5172413793103449
#
# Iteration : 30: Test Accuracy = 0.999597
# Iteration : 30: Test Precision = 0.999195
# Iteration : 30: Test Recall = 1.000000
# Iteration : 30: Test F1 = 0.999597
# Iteration : 30: Fraction of allowed points in labeled dataset = 0.5166666666666667
#
# Iteration : 31: Test Accuracy = 0.999587
# Iteration : 31: Test Precision = 0.999174
# Iteration : 31: Test Recall = 1.000000
# Iteration : 31: Test F1 = 0.999587
# Iteration : 31: Fraction of allowed points in labeled dataset = 0.532258064516129
#
# Iteration : 32: Test Accuracy = 0.999544
# Iteration : 32: Test Precision = 0.999089
# Iteration : 32: Test Recall = 1.000000
# Iteration : 32: Test F1 = 0.999544
# Iteration : 32: Fraction of allowed points in labeled dataset = 0.546875
#
# Iteration : 33: Test Accuracy = 0.999608
# Iteration : 33: Test Precision = 0.999216
# Iteration : 33: Test Recall = 1.000000
# Iteration : 33: Test F1 = 0.999608
# Iteration : 33: Fraction of allowed points in labeled dataset = 0.5303030303030303
#
# Iteration : 34: Test Accuracy = 0.999460
# Iteration : 34: Test Precision = 0.998941
# Iteration : 34: Test Recall = 0.999979
# Iteration : 34: Test F1 = 0.999460
# Iteration : 34: Fraction of allowed points in labeled dataset = 0.5441176470588235
#
# Iteration : 35: Test Accuracy = 0.999566
# Iteration : 35: Test Precision = 0.999131
# Iteration : 35: Test Recall = 1.000000
# Iteration : 35: Test F1 = 0.999566
# Iteration : 35: Fraction of allowed points in labeled dataset = 0.5428571428571428
# Iteration : 36: Test Accuracy = 0.999544
# Iteration : 36: Test Precision = 0.999089
# Iteration : 36: Test Recall = 1.000000
# Iteration : 36: Test F1 = 0.999544
# Iteration : 36: Fraction of allowed points in labeled dataset = 0.5416666666666666
#
# Iteration : 37: Test Accuracy = 0.999576
# Iteration : 37: Test Precision = 0.999153
# Iteration : 37: Test Recall = 1.000000
# Iteration : 37: Test F1 = 0.999576
# Iteration : 37: Fraction of allowed points in labeled dataset = 0.5540540540540541
#
# Iteration : 38: Test Accuracy = 0.999555
# Iteration : 38: Test Precision = 0.999110
# Iteration : 38: Test Recall = 1.000000
# Iteration : 38: Test F1 = 0.999555
# Iteration : 38: Fraction of allowed points in labeled dataset = 0.5657894736842105
#
# Iteration : 39: Test Accuracy = 0.999619
# Iteration : 39: Test Precision = 0.999237
# Iteration : 39: Test Recall = 1.000000
# Iteration : 39: Test F1 = 0.999618
# Iteration : 39: Fraction of allowed points in labeled dataset = 0.5769230769230769
#
# Iteration : 40: Test Accuracy = 0.999597
# Iteration : 40: Test Precision = 0.999195
# Iteration : 40: Test Recall = 1.000000
# Iteration : 40: Test F1 = 0.999597
# Iteration : 40: Fraction of allowed points in labeled dataset = 0.5875
#
# Final Model Test Accuracy: 0.999555
# Final Model Test Precision: 0.999110
# Final Model Test Recall: 1.000000
# Final Model Test F1: 0.999555
# Fraction of allowed points in labeled dataset: 0.5975609756097561

# %%
# Plot iteration vs accuracy

plt.figure(figsize=(10, 9))

plt.subplot(2,2,1)
plt.plot(num_it_array, accuracy_array)
plt.title("Plot of iterations vs accuracy")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")

# Plot iteration vs precision

plt.subplot(2,2,2)
plt.plot(num_it_array, precision_array)
plt.title("Plot of iterations vs precision")
plt.xlabel("Iteration")
plt.ylabel("Precision")

# Plot iteration vs recall

plt.subplot(2,2,3)
plt.plot(num_it_array, recall_array)
plt.title("Plot of iterations vs recall")
plt.xlabel("Iteration")
plt.ylabel("Recall")

# Plot iteration vs f1-score

plt.subplot(2,2,4)
plt.plot(num_it_array, f1_array)
plt.title("Plot of iterations vs f1-score")
plt.xlabel("Iteration")
plt.ylabel("F1-score")
# Out:
# Text(0, 0.5, 'F1-score')
